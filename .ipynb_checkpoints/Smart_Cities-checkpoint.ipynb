# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Загружаем данные с рейтингами IESE, с 2014 по 2019 гг.

# %%
rank_2014 = pd.read_excel('IESE_2014_City_Ranking.xlsx').filter(items =["Ranking 2014", 'City', 'Country', "CIMI 2014"])
rank_2015 = pd.read_excel('IESE_2015_City_Ranking.xlsx').filter(items =["Ranking 2015", 'City', 'Country', "CIMI 2015"])
rank_2016 = pd.read_excel('IESE_2016_City_Ranking.xlsx').filter(items =["Ranking 2016", 'City', 'Country', "CIMI 2016"])
rank_2017 = pd.read_excel('IESE_2017_City_Ranking.xlsx').filter(items =["Ranking 2017", 'City', 'Country', "CIMI 2017"])
rank_2018 = pd.read_excel('IESE_2018_City_Ranking.xlsx').filter(items =["Ranking 2018", 'City', 'Country', "CIMI 2018"])
rank_2019 = pd.read_excel('IESE_2019_City_Ranking.xlsx').filter(items =["Ranking 2019", 'City', 'Country', "CIMI 2019"])
rank_2019 # Выведено для проверки, что данные грузятся нормально
# Out:
#      Ranking 2019           City         Country  CIMI 2019
# 0               1         London  United Kingdom     100.00
# 1               2  New York City   United States      95.73
# 2               3          Paris          France      85.50
# 3               4          Tokyo           Japan      81.95
# 4               5      Reykjavik         Iceland      80.47
# ..            ...            ...             ...        ...
# 169           170         Douala        Cameroon      22.58
# 170           171          Lagos         Nigeria      18.13
# 171           172         Lahore        Pakistan      13.76
# 172           173        Karachi        Pakistan      10.39
# 173           174        Caracas       Venezuela       4.15
#
# [174 rows x 4 columns]

# %% [markdown]
# При первоначальной загрузке данных была логическая ошибка. Были выбраны к загрузке только столбцы: город-рейтинг, оказалось, что в одной из таблиц два города Лондон (один в Англии, другой в Канаде). Перевыбраны столбцы: город-страна-рейтинг.
# Далее оказалось, что были ошибки в названии стран (не все были идентичны). В исходных данных проверка/исправление в справочнике городов и стран.

# %%
rank_2015[rank_2015.City == 'London']
# Out:
#     Ranking 2015    City         Country  CIMI 2015
# 1              2  London  United Kingdom      99.65
# 36            37  London          Canada      77.32

# %%
rank_2015[rank_2015.City == 'New York City'][rank_2015.Country == 'United States']
# Out:
# <ipython-input-5-15d27a61ca71>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   rank_2015[rank_2015.City == 'New York City'][rank_2015.Country == 'United States']
#    Ranking 2015           City        Country  CIMI 2015
# 0             1  New York City  United States      100.0

# %% [markdown]
# ### Состав индикаторов и категорий рейтингов 2014 и 2019 гг.

# %%
# Загружаем перечень индикаторов и категорий, группируем по категориям, для 2019 и 2019 гг.
indicator_list_2019 = pd.read_excel('IESE_2019_CIMI_indicator_list.xlsx', sheet_name='Dimensions')
indicator_list_2019 = indicator_list_2019.groupby('Dimensions').count().rename(columns={"Indicator": "Indicator 2019"})
indicator_list_2019
# Out:
#                              No  Indicator 2019  \
# Dimensions
# Economy                      12              12
# Environment                  11              11
# Governance                   12              12
# Human Capital                10              10
# International Projection      6               6
# Mobility and Transportation  13              13
# Social Cohesion              15              15
# Technology                   17              17
# Urban Planning                5               5
#
#                              Description/Unit of measurement  Source
# Dimensions
# Economy                                                   12      12
# Environment                                               11      11
# Governance                                                12      12
# Human Capital                                             10      10
# International Projection                                   6       6
# Mobility and Transportation                               13      13
# Social Cohesion                                           15      15
# Technology                                                17      17
# Urban Planning                                             5       5

# %%
indicator_list_2014 = pd.read_excel('IESE_2014_CIMI_indicator_list.xlsx')
indicator_list_2014 = indicator_list_2014.groupby('Dimensions').count().rename(columns={"Indicator": "Indicator 2014"})
indicator_list_2014
# Out:
#                              No  Indicator 2014  Initials  \
# Dimensions
# City Cluster                  6               6         6
# Country Cluster               5               5         5
# Economy                       6               6         6
# Environment                   8               8         8
# Governance                    4               4         4
# Human Capital                 7               7         7
# International Outreach        5               5         5
# Mobility and Transportation   5               5         5
# Public Management             7               7         7
# Social Cohesion               6               6         6
# Technology                    8               8         8
# Urban Planning                5               5         5
#
#                              Description/Unit of measurement  Source
# Dimensions
# City Cluster                                               6       6
# Country Cluster                                            5       5
# Economy                                                    6       6
# Environment                                                8       8
# Governance                                                 4       4
# Human Capital                                              7       7
# International Outreach                                     5       5
# Mobility and Transportation                                5       5
# Public Management                                          7       7
# Social Cohesion                                            6       6
# Technology                                                 8       8
# Urban Planning                                             5       5

# %%
indicator_list_2014_2019 = indicator_list_2014.merge(
    indicator_list_2019, how = 'outer', on = 'Dimensions').fillna(0).filter(
    items = ['Dimensions', 'Indicator 2014', 'Indicator 2019']).sort_values(by = 'Dimensions')
indicator_list_2014_2019 = indicator_list_2014_2019.convert_dtypes()
indicator_list_2014_2019.loc['Total'] = indicator_list_2014_2019.sum(numeric_only=True)
indicator_list_2014_2019
# Получили таблицу индикаторов для подсчета CIMI в 2014 и 2019 гг. 
# Видно, что больше показателей стало во всех категориях (Public Management и Governance объединились).
# Out:
#                              Indicator 2014  Indicator 2019
# Dimensions
# City Cluster                              6               0
# Country Cluster                           5               0
# Economy                                   6              12
# Environment                               8              11
# Governance                                4              12
# Human Capital                             7              10
# International Outreach                    5               0
# International Projection                  0               6
# Mobility and Transportation               5              13
# Public Management                         7               0
# Social Cohesion                           6              15
# Technology                                8              17
# Urban Planning                            5               5
# Total                                    72             101

# %% [markdown]
# Загружаем рейтинг 2019 г. с общим рейтингом и местами, занятыми в каждом из 9 блоков.

# %%
full_rank_2019 = pd.read_excel('IESE_2019_full_data.xlsx')
full_rank_2019
# Ограничение: полные данные с рейтингами по категориям рассмотрены только для топ-116 городов 
# из всех 174 городов.
# Out:
#     City_origin  Country_origin           City         Country  Ranking 2019  \
# 0        London  United Kingdom         London  United Kingdom             1
# 1      New York             USA  New York City   United States             2
# 2         Paris          France          Paris          France             3
# 3         Tokyo           Japan          Tokyo           Japan             4
# 4     Reykjavík         Iceland      Reykjavik         Iceland             5
# ..          ...             ...            ...             ...           ...
# 111     Bangkok        Thailand        Bangkok        Thailand           112
# 112      Panama          Panama    Panama City          Panama           113
# 113    San José      Costa Rica       San Jose      Costa Rica           114
# 114        Kiev         Ukraine           Kiev         Ukraine           115
# 115       Sofia        Bulgaria          Sofia        Bulgaria           116
#
#      Economy  Human capital  Social cohesion  Environment  Governance  \
# 0         14              1               64           35           2
# 1          1              3              151           69          30
# 2         13              6               74           48          44
# 3          3              9               51            6          26
# 4         86             22               14            1          25
# ..       ...            ...              ...          ...         ...
# 111      125            129              116          121         152
# 112       84            145              103           40         149
# 113      123            155              112           14          77
# 114      133            104              160          123          93
# 115      162             77               66           88          59
#
#      Urban planning  International projection  Technology  \
# 0                 2                         1           6
# 1                 1                         6           8
# 2                12                         2          20
# 3                23                        30          22
# 4               125                        16          58
# ..              ...                       ...         ...
# 111              27                        15         109
# 112              50                        80         151
# 113             132                       101         132
# 114               4                       117         152
# 115             153                       104         118
#
#      Mobility and Transportation
# 0                              3
# 1                              1
# 2                              2
# 3                             56
# 4                             57
# ..                           ...
# 111                          117
# 112                          140
# 113                          144
# 114                          124
# 115                          104
#
# [116 rows x 14 columns]

# %% [markdown]
# ### Связь между категориями показателей

# %% [markdown]
# Смотрим зависимости между рейтингами по категориям, 2019 год - на диаграмме рассеяния и через коэф-ты корреляции

# %%
# Весовые коэф-ты категорий в 2019 г.
weight_2019 = pd.read_excel('IESE_2019_CIMI_indicator_list.xlsx', sheet_name='Weight').sort_values(
    by = 'Weight', ascending = False)
weight_2019
# Out:
#                      Dimension  Weight
# 0                      Economy   1.000
# 1                  Environment   0.820
# 3                Human Capital   0.661
# 5  Mobility and Transportation   0.556
# 4     International Projection   0.543
# 6              Social Cohesion   0.488
# 8               Urban Planning   0.474
# 2                   Governance   0.416
# 7                   Technology   0.343

# %%
full_rank_2019_visual = full_rank_2019.filter(items = ['Ranking 2019', 'Economy', 'Human capital', 'Social cohesion',
                                                       'Environment', 'Governance', 'Urban planning', 
                                                       'International projection', 'Technology', 'Mobility and Transportation'])
# g = sns.pairplot(full_rank_2019_visual, kind = 'scatter', height = 1, corner=True)
# g.set_xticklabels(rotation=90) 
# sns.set_yticklabels(rotation=90) 

sns.pairplot(full_rank_2019_visual, kind="kde", corner=True)

# %%
# full_rank_2019_visual.corr(method='kendall')
# full_rank_2019_visual.corr(method='spearman')
full_rank_2019_visual.corr()
# Out:
#                              Ranking 2019   Economy  Human capital  \
# Ranking 2019                     1.000000  0.719816       0.712948
# Economy                          0.719816  1.000000       0.476771
# Human capital                    0.712948  0.476771       1.000000
# Social cohesion                  0.263856  0.042540      -0.085135
# Environment                      0.308003 -0.114120      -0.033690
# Governance                       0.743060  0.434567       0.564213
# Urban planning                   0.531847  0.395399       0.459799
# International projection         0.665437  0.413934       0.450432
# Technology                       0.723246  0.694773       0.530887
# Mobility and Transportation      0.362682  0.130450       0.206748
#
#                              Social cohesion  Environment  Governance  \
# Ranking 2019                        0.263856     0.308003    0.743060
# Economy                             0.042540    -0.114120    0.434567
# Human capital                      -0.085135    -0.033690    0.564213
# Social cohesion                     1.000000     0.385146    0.285898
# Environment                         0.385146     1.000000    0.230388
# Governance                          0.285898     0.230388    1.000000
# Urban planning                     -0.121496    -0.046787    0.397516
# International projection           -0.051432     0.107483    0.412199
# Technology                          0.175168    -0.005383    0.530368
# Mobility and Transportation         0.161322     0.123877    0.033978
#
#                              Urban planning  International projection  \
# Ranking 2019                       0.531847                  0.665437
# Economy                            0.395399                  0.413934
# Human capital                      0.459799                  0.450432
# Social cohesion                   -0.121496                 -0.051432
# Environment                       -0.046787                  0.107483
# Governance                         0.397516                  0.412199
# Urban planning                     1.000000                  0.329566
# International projection           0.329566                  1.000000
# Technology                         0.317206                  0.419507
# Mobility and Transportation        0.068061                  0.286725
#
#                              Technology  Mobility and Transportation
# Ranking 2019                   0.723246                     0.362682
# Economy                        0.694773                     0.130450
# Human capital                  0.530887                     0.206748
# Social cohesion                0.175168                     0.161322
# Environment                   -0.005383                     0.123877
# Governance                     0.530368                     0.033978
# Urban planning                 0.317206                     0.068061
# International projection       0.419507                     0.286725
# Technology                     1.000000                     0.159336
# Mobility and Transportation    0.159336                     1.000000

# %%
sns.heatmap(full_rank_2019_visual.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# У итогового рейтинга высокие коэф-ты корреляции с: Управлением (0,74), Экономикой (0,72), Технологиями (0,72), Человеческим капиталом (0,71) и Международными связями (0,67).
# Между отдельными категориями высокие корреляции:
# Экономика - Технология (0,69),
# Человеческий капитал - Управление (0,53),
# Управление - Технология (0,53)

# %% [markdown]
# ### Зависимость между ВВП страны на душу населения страны и рейтингом города в 2019 г.

# %%
GDP_per_capita = pd.read_excel('GDP_per_capita.xlsx', sheet_name='Prepared').filter(
    items =['Country', "GDP per capita in USD"])
GDP_in_rank_2019 = rank_2019.merge(GDP_per_capita, on = ['Country']).loc[
    :,['City', 'Country', "Ranking 2019", "CIMI 2019",  "GDP per capita in USD"]]
GDP_in_rank_2019
# Out:
#            City         Country  Ranking 2019  CIMI 2019  \
# 0        London  United Kingdom             1     100.00
# 1     Edinburgh  United Kingdom            47      63.94
# 2       Glasgow  United Kingdom            66      59.58
# 3    Manchester  United Kingdom            71      58.97
# 4    Birmingham  United Kingdom            73      58.63
# ..          ...             ...           ...        ...
# 168      Douala        Cameroon           170      22.58
# 169       Lagos         Nigeria           171      18.13
# 170      Lahore        Pakistan           172      13.76
# 171     Karachi        Pakistan           173      10.39
# 172     Caracas       Venezuela           174       4.15
#
#      GDP per capita in USD
# 0                   40.285
# 1                   40.285
# 2                   40.285
# 3                   40.285
# 4                   40.285
# ..                     ...
# 168                  1.499
# 169                  2.097
# 170                  1.194
# 171                  1.194
# 172                 16.056
#
# [173 rows x 5 columns]

# %%
GDP_in_rank_2019.plot.scatter(
    x = 'GDP per capita in USD',
    y = 'Ranking 2019')
# Out:
# <AxesSubplot:xlabel='GDP per capita in USD', ylabel='Ranking 2019'>

# %%
GDP_in_rank_2019.plot.scatter(
    x = 'GDP per capita in USD',
    y = 'CIMI 2019')
# Out:
# <AxesSubplot:xlabel='GDP per capita in USD', ylabel='CIMI 2019'>

# %%
GDP_in_rank_2019[['GDP per capita in USD', 'Ranking 2019', 'CIMI 2019']].corr()
# Прослеживается связь между ВВП страны на душу населения и местом в рейтинге, индексом CIMI.
# Это ожидаемо, в т.ч. потому что ВВП входит к один из показателей для определения индекса CIMI, в блок Экономики, 
# который вносит существенный вклад в индекс, коэф-т корреляции общего индекса и индекса Экономики в 2019 г. - 0,72
# Out:
#                        GDP per capita in USD  Ranking 2019  CIMI 2019
# GDP per capita in USD               1.000000     -0.781160   0.734862
# Ranking 2019                       -0.781160      1.000000  -0.972428
# CIMI 2019                           0.734862     -0.972428   1.000000

# %% [markdown]
# Подбираем модель линейной регрессии между ВВП на душу населения и рейтингом 2019 г.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = GDP_in_rank_2019[['GDP per capita in USD']]
y = GDP_in_rank_2019['Ranking 2019']

model_GDP = LinearRegression()
model_GDP = model_GDP.fit(X, y) 

model_GDP.coef_
model_GDP.intercept_
print(model_GDP.coef_, model_GDP.intercept_) # Коэф-ты уравнения регрессии
# Out:
# [-1.73510776] 138.57357035285523

# %%
y_index_model = model_GDP.predict(X)
model_GDP.score(X, y_index_model) # метод возвращает значение коэффициента детерминации. Равно 1, т.к. в точности по этим данным подобрано.
# Out:
# 1.0

# %%
GDP_in_rank_2019.plot.scatter(
    x = 'GDP per capita in USD',
    y = 'Ranking 2019')
plt.plot(X, y_index_model, color = 'r')
# На графике видно, что тренд соответствует данным, но разброс отдельных параметров большой.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
model_GDP_pred = LinearRegression()
model_GDP_pred.fit(X_train, y_train)
model_GDP_pred.score(X_test, y_test) 
# Коэф-т детерминации на тестовой выборке 30% - 0,68. 
# Это подтверждает, что уравнение регрессии тенденцию отражает, но с существенным разбросом
# Out:
# 0.6804635133155363

# %%
y_index_model_pred = model_GDP_pred.predict(X_test)

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_index_model_pred, color = 'y')

# %% [markdown]
# ### Индексы - CIMI

# %%
# Смотрим, как распределяются индексы в рейтингах
rank_2014['CIMI 2014'].plot(kind='hist', 
                     bins=10,
                     title='CIMI 2014 distribution',
                     #xlabel='CIMI',
                     #ylabel='',
                     xticks=range(0, 100, 10))
# Out:
# <AxesSubplot:title={'center':'CIMI 2014 distribution'}, ylabel='Frequency'>

# %%
rank_2017['CIMI 2017'].plot(kind='hist', 
                     bins=10,
                     title='CIMI 2017 distribution',
                     #xlabel='CIMI',
                     #ylabel='',
                     xticks=range(0, 100, 10))
# Out:
# <AxesSubplot:title={'center':'CIMI 2017 distribution'}, ylabel='Frequency'>

# %%
rank_2019['CIMI 2019'].plot(kind='hist', 
                     bins=10,
                     title='CIMI 2019 distribution',
                     #xlabel='CIMI',
                     #ylabel='',
                     xticks=range(0, 100, 10))
# Видно, что в 2014 г. нет аутсайдеров, большее количество в середнячках и выше.
# В 2017, 2019 гг. в рейтинге присутствуют города с низкими оценками. 
# Возможно, за счет того, что количество оценочных показателей стало больше, находятся города,
# которые хоть в чем-то могут отличиться и набрать баллы для итогового индекса.
# Out:
# <AxesSubplot:title={'center':'CIMI 2019 distribution'}, ylabel='Frequency'>

# %%
CIMI_2014 = rank_2014['CIMI 2014']
CIMI_2015 = rank_2015['CIMI 2015']
CIMI_2017 = rank_2017['CIMI 2017']
CIMI_2019 = rank_2019['CIMI 2019']


fig, ax = plt.subplots()
bins = 10
ax.hist(CIMI_2014, density=True, fill = True, histtype='step', label = 'CIMI_2014')
# ax.hist(CIMI_2015, density=True, fill = True, histtype='step', label = 'CIMI_2015')
ax.hist(CIMI_2017, density=True, fill = False, histtype='step', label = 'CIMI_2017')
ax.hist(CIMI_2019, density=True, fill = False, histtype='step', label = 'CIMI_2019')


plt.legend()
plt.title('Распределение CIMI')
plt.show()

# %%
print(rank_2014['CIMI 2014'].min(), 
      rank_2015['CIMI 2015'].min(), 
      rank_2016['CIMI 2016'].min(), 
      rank_2017['CIMI 2017'].min(), 
      rank_2018['CIMI 2018'].min(), 
      rank_2019['CIMI 2019'].min())
# Out:
# 35.35 32.86 32.74 17.23 4.57 4.15

# %%
print(rank_2014['CIMI 2014'].count(), 
      rank_2015['CIMI 2015'].count(), 
      rank_2016['CIMI 2016'].count(), 
      rank_2017['CIMI 2017'].count(), 
      rank_2018['CIMI 2018'].count(), 
      rank_2019['CIMI 2019'].count())
# Out:
# 148 181 180 165 174 174

# %%
count = (rank_2014['CIMI 2014'].count(), 
      rank_2015['CIMI 2015'].count(), 
      rank_2016['CIMI 2016'].count(), 
      rank_2017['CIMI 2017'].count(), 
      rank_2018['CIMI 2018'].count(), 
      rank_2019['CIMI 2019'].count())
years = {'2014', '2015', '2016', '2017', '2018', '2019'}

city_count = pd.DataFrame({"Years": ['2014', '2015', '2016', '2017', '2018', '2019'],
                           "City count": list(count)}, 
                          columns = ["Years", "City count"]).transpose()

city_count = city_count.rename(columns=city_count.iloc[0]).drop(city_count.index[0])

city_count
# Out:
#            2014 2015 2016 2017 2018 2019
# City count  148  181  180  165  174  174

# %% [markdown]
# ### Средние значения рейтингов и индексов с 2014 по 2019 гг.

# %% [markdown]
# Формируем таблицу из всех городов, которые попадали во все рейтинги - "узкий" список.

# %%
rank_2014_2019_inner = rank_2014.merge(rank_2015, how = 'inner', on = ['City', 'Country']).merge(rank_2016, 
                how = 'inner', on = ['City', 'Country']).merge(rank_2017, 
                how = 'inner', on = ['City', 'Country']).merge(rank_2018, 
                how = 'inner', on = ['City', 'Country']).merge(rank_2019, 
                how = 'inner', on = ['City', 'Country'])
rank_2014_2019_inner.sort_values(by='Ranking 2019', ascending=True)
# Out:
#      Ranking 2014           City         Country  CIMI 2014  Ranking 2015  \
# 0               1         London  United Kingdom     100.00             2
# 1               2  New York City   United States      92.24             1
# 3               4          Paris          France      87.69             3
# 6               7          Tokyo           Japan      84.15            12
# 14             15     Copenhagen         Denmark      80.48            11
# ..            ...            ...             ...        ...           ...
# 108           127         Manila     Philippines      44.24           145
# 93            105         Riyadh    Saudi Arabia      51.91           123
# 113           137          Cairo           Egypt      40.77           156
# 118           148       Calcutta           India      35.35           179
# 117           147        Caracas       Venezuela      35.83           162
#
#      CIMI 2015  Ranking 2016  CIMI 2016  Ranking 2017  CIMI 2017  \
# 0        99.65             2      98.71             2      99.27
# 1       100.00             1     100.00             1     100.00
# 3        92.89             3      91.97             3      90.20
# 6        85.12             8      84.85             4      84.38
# 14       86.00            27      77.56            13      74.55
# ..         ...           ...        ...           ...        ...
# 108      49.55           148      46.51           146      32.73
# 93       55.78           138      48.32           153      29.13
# 113      45.47           163      42.30           157      27.24
# 118      37.67           178      34.54           163      21.14
# 117      43.32           173      38.03           162      21.38
#
#      Ranking 2018  CIMI 2018  Ranking 2019  CIMI 2019
# 0               1     100.00             1     100.00
# 1               2      94.63             2      95.73
# 3               4      86.23             3      85.50
# 6               6      84.11             4      81.95
# 14              8      81.80             6      78.51
# ..            ...        ...           ...        ...
# 108           163      27.73           165      29.56
# 93            164      27.71           167      29.34
# 113           165      26.74           168      26.89
# 118           169      19.54           169      26.35
# 117           172       6.71           174       4.15
#
# [119 rows x 14 columns]

# %%
# Формируем таблицу "узкого" списка только с рейтинговыми местами в каждом году
r1 = rank_2014_2019_inner.loc[:,['City', 'Country', 'Ranking 2014', 'Ranking 2015', 'Ranking 2016', 
                           'Ranking 2017', 'Ranking 2018', 'Ranking 2019']].sort_values(by='Ranking 2019', ascending=True)
r1
# Out:
#               City         Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# 0           London  United Kingdom             1             2             2
# 1    New York City   United States             2             1             1
# 3            Paris          France             4             3             3
# 6            Tokyo           Japan             7            12             8
# 14      Copenhagen         Denmark            15            11            27
# ..             ...             ...           ...           ...           ...
# 108         Manila     Philippines           127           145           148
# 93          Riyadh    Saudi Arabia           105           123           138
# 113          Cairo           Egypt           137           156           163
# 118       Calcutta           India           148           179           178
# 117        Caracas       Venezuela           147           162           173
#
#      Ranking 2017  Ranking 2018  Ranking 2019
# 0               2             1             1
# 1               1             2             2
# 3               3             4             3
# 6               4             6             4
# 14             13             8             6
# ..            ...           ...           ...
# 108           146           163           165
# 93            153           164           167
# 113           157           165           168
# 118           163           169           169
# 117           162           172           174
#
# [119 rows x 8 columns]

# %% [markdown]
# Добавим столбец со средним рейтингом за 6 лет. Посмотрим графически, что получается

# %%
r1['average_rating'] = r1[['Ranking 2014', 'Ranking 2015', 'Ranking 2016', 
                           'Ranking 2017', 'Ranking 2018', 'Ranking 2019']].mean(axis=1).round(2)
r1
# Out:
#               City         Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# 0           London  United Kingdom             1             2             2
# 1    New York City   United States             2             1             1
# 3            Paris          France             4             3             3
# 6            Tokyo           Japan             7            12             8
# 14      Copenhagen         Denmark            15            11            27
# ..             ...             ...           ...           ...           ...
# 108         Manila     Philippines           127           145           148
# 93          Riyadh    Saudi Arabia           105           123           138
# 113          Cairo           Egypt           137           156           163
# 118       Calcutta           India           148           179           178
# 117        Caracas       Venezuela           147           162           173
#
#      Ranking 2017  Ranking 2018  Ranking 2019  average_rating
# 0               2             1             1            1.50
# 1               1             2             2            1.50
# 3               3             4             3            3.33
# 6               4             6             4            6.83
# 14             13             8             6           13.33
# ..            ...           ...           ...             ...
# 108           146           163           165          149.00
# 93            153           164           167          141.67
# 113           157           165           168          157.67
# 118           163           169           169          167.67
# 117           162           172           174          165.00
#
# [119 rows x 9 columns]

# %%
# Посмотрим разброс рейтингов - стандартное отклонение
r1['stdev_rating'] = np.std(r1[['Ranking 2014', 'Ranking 2015', 'Ranking 2016', 
                           'Ranking 2017', 'Ranking 2018', 'Ranking 2019']], axis=1).round(2)
r1
# Out:
#               City         Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# 0           London  United Kingdom             1             2             2
# 1    New York City   United States             2             1             1
# 3            Paris          France             4             3             3
# 6            Tokyo           Japan             7            12             8
# 14      Copenhagen         Denmark            15            11            27
# ..             ...             ...           ...           ...           ...
# 108         Manila     Philippines           127           145           148
# 93          Riyadh    Saudi Arabia           105           123           138
# 113          Cairo           Egypt           137           156           163
# 118       Calcutta           India           148           179           178
# 117        Caracas       Venezuela           147           162           173
#
#      Ranking 2017  Ranking 2018  Ranking 2019  average_rating  stdev_rating
# 0               2             1             1            1.50          0.50
# 1               1             2             2            1.50          0.50
# 3               3             4             3            3.33          0.47
# 6               4             6             4            6.83          2.73
# 14             13             8             6           13.33          6.80
# ..            ...           ...           ...             ...           ...
# 108           146           163           165          149.00         12.66
# 93            153           164           167          141.67         22.27
# 113           157           165           168          157.67         10.16
# 118           163           169           169          167.67         10.39
# 117           162           172           174          165.00          9.45
#
# [119 rows x 10 columns]

# %%
r1['stdev_rating'].mean()
# Получили среднее значение стандартных отклонений по "узкому" списку рейтингов
# Out:
# 10.181344537815127

# %%
r1_stdev_less10 = r1[r1['stdev_rating'] < 10]
r1_stdev_less10['stdev_rating'].count()
r1['stdev_rating'].count()
round(r1_stdev_less10['stdev_rating'].count()/r1['stdev_rating'].count()*100, 2)
# Получили процент городов, у которых по узкому списку станд. отклонения рейтинга менее 10 
# Это те, кто стабильно держат свои места все шесть лет. Такие города есть на всем протяжении списка.
# Out:
# 54.62

# %%
# Строим график рассеяния между средним и стандартным отклонением. 
# Разброс есть, то тенденции по увеличению разброса в зависимости от рейтинга нет (кроме топ-10)
r1.plot(kind='scatter', 
        x='average_rating', 
        y='stdev_rating' 
        )
plt.title('Узкий список рейтингов 2014-2019 гг.')
plt.show()

# %%
# График распределения стандартных отклонений - почти нормальный.
# r1['stdev_rating'].plot.hist()
sns.histplot(data=r1['stdev_rating'], kde=True)
# Out:
# <AxesSubplot:xlabel='stdev_rating', ylabel='Count'>

# %%
r1.plot(kind='scatter', 
        x='Ranking 2019', 
        y='average_rating' 
        )
plt.title('Узкий список рейтингов 2014-2019 гг.')
plt.show()
#Кучность высокая - рейтинг 2019 г. примерно соответствует среднему рейтингу за 6 лет.

# %%
r1.plot(kind='scatter', 
        x='Ranking 2014', 
        y='average_rating' 
        )
plt.title('Узкий список рейтингов 2014-2019 гг.')
plt.show()
#Не такая кучная распределенность. 
#Есть случаи, когда рейтинги 2014 г. сильно лучше (маленькие значения), чем средний рейтинг за 6 лет.

# %%
r1.plot(kind='scatter', 
        x='Ranking 2019', 
        y='Ranking 2014' 
        )
plt.title('Узкий список рейтингов 2014-2019 гг.')
plt.show()
#Видно, что места в 2014 и в 2019 гг. могут существенно отличаться. 
#В первых 15 местах разброса почти нет - те же самые лидеры.

# %%
r1.plot(kind='scatter', 
        x='Ranking 2019', 
        y='Ranking 2014' 
        )
#x1,x2,y1,y2 = plt.axis()
plt.axis((0,30,0,30))
plt.title('Узкий список рейтингов 2014-2019 гг.')
plt.show()

# %%
dimension = r1['average_rating']
r1.plot(kind='scatter', 
        x='Ranking 2019', 
        y='Ranking 2014', 
        s = dimension)
plt.title('Узкий список рейтингов 2014-2019 гг.')
plt.show()

# %% [markdown]
# Формируем "узкую" таблицу с индексами CIMI, выводим средний индекс за все годы

# %%
r2 = rank_2014_2019_inner.loc[:,['City', 'Country', 'CIMI 2014', 'CIMI 2015', 'CIMI 2016', 
                           'CIMI 2017', 'CIMI 2018', 'CIMI 2019']].sort_values(by='CIMI 2019', ascending=False)
r2
# Out:
#               City         Country  CIMI 2014  CIMI 2015  CIMI 2016  \
# 0           London  United Kingdom     100.00      99.65      98.71
# 1    New York City   United States      92.24     100.00     100.00
# 3            Paris          France      87.69      92.89      91.97
# 6            Tokyo           Japan      84.15      85.12      84.85
# 14      Copenhagen         Denmark      80.48      86.00      77.56
# ..             ...             ...        ...        ...        ...
# 108         Manila     Philippines      44.24      49.55      46.51
# 93          Riyadh    Saudi Arabia      51.91      55.78      48.32
# 113          Cairo           Egypt      40.77      45.47      42.30
# 118       Calcutta           India      35.35      37.67      34.54
# 117        Caracas       Venezuela      35.83      43.32      38.03
#
#      CIMI 2017  CIMI 2018  CIMI 2019
# 0        99.27     100.00     100.00
# 1       100.00      94.63      95.73
# 3        90.20      86.23      85.50
# 6        84.38      84.11      81.95
# 14       74.55      81.80      78.51
# ..         ...        ...        ...
# 108      32.73      27.73      29.56
# 93       29.13      27.71      29.34
# 113      27.24      26.74      26.89
# 118      21.14      19.54      26.35
# 117      21.38       6.71       4.15
#
# [119 rows x 8 columns]

# %%
r2['average_CIMI'] = r2[['CIMI 2014', 'CIMI 2015', 'CIMI 2016', 
                           'CIMI 2017', 'CIMI 2018', 'CIMI 2019']].mean(axis=1).round(2)
r2_sorted_by_ave_CIMI = r2.sort_values(by='average_CIMI', ascending=False)
r2_sorted_by_ave_CIMI
# Out:
#               City             Country  CIMI 2014  CIMI 2015  CIMI 2016  \
# 0           London      United Kingdom     100.00      99.65      98.71
# 1    New York City       United States      92.24     100.00     100.00
# 3            Paris              France      87.69      92.89      91.97
# 6            Tokyo               Japan      84.15      85.12      84.85
# 4        Amsterdam         Netherlands      85.05      90.32      82.86
# ..             ...                 ...        ...        ...        ...
# 116  Santo Domingo  Dominican Republic      36.58      39.88      40.34
# 115         La Paz             Bolivia      36.93      41.67      39.25
# 113          Cairo               Egypt      40.77      45.47      42.30
# 118       Calcutta               India      35.35      37.67      34.54
# 117        Caracas           Venezuela      35.83      43.32      38.03
#
#      CIMI 2017  CIMI 2018  CIMI 2019  average_CIMI
# 0        99.27     100.00     100.00         99.60
# 1       100.00      94.63      95.73         97.10
# 3        90.20      86.23      85.50         89.08
# 6        84.38      84.11      81.95         84.09
# 4        77.44      86.70      77.31         83.28
# ..         ...        ...        ...           ...
# 116      29.10      37.43      40.39         37.29
# 115      30.08      35.12      35.88         36.49
# 113      27.24      26.74      26.89         34.90
# 118      21.14      19.54      26.35         29.10
# 117      21.38       6.71       4.15         24.90
#
# [119 rows x 9 columns]

# %%
x = r2_sorted_by_ave_CIMI['City'] 
y = r2_sorted_by_ave_CIMI['average_CIMI'] 
# plt.bar(x, y)
        
fig, ax = plt.subplots()
ax.bar(x, y)
ax.set_xticks([])

fig.set_figwidth(18)    #  ширина Figure
fig.set_figheight(5)    #  высота Figure

plt.show()

# %%
# Отбираем топ-20 городов по среднему значение индекса за 6 лет из "узкого" списка. 
# Затем покажем графически индексы 2014, 2017 и 2019 гг.
r2_20 = r2_sorted_by_ave_CIMI.iloc[:20]
r2_20
# Out:
#              City         Country  CIMI 2014  CIMI 2015  CIMI 2016  CIMI 2017  \
# 0          London  United Kingdom     100.00      99.65      98.71      99.27
# 1   New York City   United States      92.24     100.00     100.00     100.00
# 3           Paris          France      87.69      92.89      91.97      90.20
# 6           Tokyo           Japan      84.15      85.12      84.85      84.38
# 4       Amsterdam     Netherlands      85.05      90.32      82.86      77.44
# 2           Seoul     South Korea      88.47      89.60      84.91      79.21
# 8       Singapore       Singapore      83.37      82.80      79.22      79.52
# 24         Berlin         Germany      78.06      84.72      83.40      76.34
# 14     Copenhagen         Denmark      80.48      86.00      77.56      74.55
# 17        Chicago   United States      80.24      90.23      82.55      73.55
# 10         Boston   United States      81.67      91.68      88.90      69.39
# 20  San Francisco   United States      79.03      92.41      88.46      67.31
# 5          Vienna         Austria      84.78      82.00      81.94      71.51
# 11         Zurich     Switzerland      81.43      85.11      82.51      68.04
# 18     Washington   United States      79.24      85.12      86.10      70.31
# 26         Sydney       Australia      77.69      86.06      81.14      73.50
# 15      Melbourne       Australia      80.44      84.69      82.06      74.91
# 23      Stockholm          Sweden      78.12      80.66      77.76      73.29
# 35        Toronto          Canada      73.36      82.78      82.85      78.16
# 16      Hong Kong           China      80.40      77.20      71.69      77.48
#
#     CIMI 2018  CIMI 2019  average_CIMI
# 0      100.00     100.00         99.60
# 1       94.63      95.73         97.10
# 3       86.23      85.50         89.08
# 6       84.11      81.95         84.09
# 4       86.70      77.31         83.28
# 2       78.13      73.67         82.33
# 8       82.73      76.71         80.73
# 24      80.88      77.46         80.14
# 14      81.80      78.51         79.82
# 17      75.55      75.04         79.53
# 10      72.91      70.71         79.21
# 20      75.07      72.40         79.11
# 5       78.85      73.84         78.82
# 11      76.66      75.96         78.28
# 18      73.14      74.32         78.04
# 26      75.26      74.07         77.95
# 15      75.08      66.50         77.28
# 23      77.89      75.00         77.12
# 35      75.30      69.17         76.94
# 16      78.76      76.04         76.93

# %%
x = r2_20['City']
y1 = r2_20['CIMI 2014']
y2 = r2_20['CIMI 2017']
y3 = r2_20['CIMI 2019']

fig, ax = plt.subplots()

ax.bar(x, y1, label = "CIMI 2014")
ax.bar(x, y2, bottom = 100, label = "CIMI 2017")
ax.bar(x, y3, bottom = 200, label = "CIMI 2019")

fig.set_figwidth(15)    #  ширина и
fig.set_figheight(4)    #  высота "Figure"
fig.set_facecolor('floralwhite')
ax.set_facecolor('seashell')

plt.xticks(rotation=90) #разворачивает надписи на оси х
ax.grid(axis = 'y')
plt.legend(loc='upper right', ncol=3)
plt.title('CIMI постоянных лидеров рейтинга с 2014 по 2019 гг.')

plt.show()

# %% [markdown]
# Объединим средние значения рейтингов и средние индексы CIMI, сделаем корреляцию и диаграмму рассеяния

# %%
r1_2 = r1.merge(r2, how = 'inner', on = ['City', 'Country']) # Объединенная таблица рейтингов, индексов за 6 лет и в среднем
r1_2.loc[:,['City', 'Country', 'average_rating', 'average_CIMI']]
# Out:
#               City         Country  average_rating  average_CIMI
# 0           London  United Kingdom            1.50         99.60
# 1    New York City   United States            1.50         97.10
# 2            Paris          France            3.33         89.08
# 3            Tokyo           Japan            6.83         84.09
# 4       Copenhagen         Denmark           13.33         79.82
# ..             ...             ...             ...           ...
# 114         Manila     Philippines          149.00         38.39
# 115         Riyadh    Saudi Arabia          141.67         40.36
# 116          Cairo           Egypt          157.67         34.90
# 117       Calcutta           India          167.67         29.10
# 118        Caracas       Venezuela          165.00         24.90
#
# [119 rows x 4 columns]

# %%
r1_2.plot(kind='scatter', 
        x='average_rating', 
        y='average_CIMI' 
        )
x1,x2,y1,y2 = plt.axis()
# plt.axis((0,30,70,100)) #График нелинейный. У топ-30 изменение индекса значительное (более 25).
# plt.axis((30,80,30,80)) #График линейный. В участниках с 30 по 80 места небольшое изменение по индексу (около 10) - середнячки.
# plt.axis((80,130,20,70)) #График линейный. В участниках с 80 по 130 места изм-е по индексу около 15, небольшое, но выше, чем в середнячках.
# plt.axis((130,170,20,60)) #График почти линейный, переходящий в конце на боле высокий темп падения. Т.е. есть аутсайдеры.
plt.title('Узкий список CIMI 2014-2019 гг.')
plt.show()

# %% [markdown]
# ### Уровни эффективности умных городов

# %%
performance_title = pd.read_excel('IESE_Performance_Title.xlsx')
performance_title
# Out:
#   Performance Title Performance Index  Score min  Score max
# 0             High                  H         91        100
# 1   Relatively High                RH         61         90
# 2            Medium                 M         46         60
# 3               Low                 L         16         45
# 4          Very Low                VL          1         15

# %%
# Функция определяет, к какой категории "хорошего" индекса отнести город.
def perf(row):
    if (row['average_CIMI'] > 90):
        return 'High'
    elif (row['average_CIMI'] > 60):
        return 'Relatively High'
    elif (row['average_CIMI'] > 45):
        return 'Medium'
    elif (row['average_CIMI'] > 15):
        return 'Low'
    else: 
        return 'Very Low'

# %%
# Добавляем категорию "хорошего" индекса в "узком" списке
r1_2['performance'] = r1_2.apply(perf, axis=1)
r1_2.head(20)
# Out:
#              City         Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# 0          London  United Kingdom             1             2             2
# 1   New York City   United States             2             1             1
# 2           Paris          France             4             3             3
# 3           Tokyo           Japan             7            12             8
# 4      Copenhagen         Denmark            15            11            27
# 5          Berlin         Germany            25            16             9
# 6       Amsterdam     Netherlands             5             6            10
# 7       Singapore       Singapore             9            22            22
# 8       Hong Kong           China            17            39            42
# 9          Zurich     Switzerland            12            14            13
# 10           Oslo          Norway            14            28            26
# 11        Chicago   United States            18             7            12
# 12      Stockholm          Sweden            24            27            25
# 13     Washington   United States            19            13             6
# 14    Los Angeles   United States            42            15            18
# 15         Sydney       Australia            27            10            16
# 16         Vienna         Austria             6            26            15
# 17          Seoul     South Korea             3             8             7
# 18  San Francisco   United States            21             4             5
# 19          Basel     Switzerland            29            42            47
#
#     Ranking 2017  Ranking 2018  Ranking 2019  average_rating  stdev_rating  \
# 0              2             1             1            1.50          0.50
# 1              1             2             2            1.50          0.50
# 2              3             4             3            3.33          0.47
# 3              4             6             4            6.83          2.73
# 4             13             8             6           13.33          6.80
# 5             11             9             7           12.83          6.12
# 6             10             3             8            7.00          2.58
# 7              6             7             9           12.50          6.80
# 8              9            11            10           21.33         13.82
# 9             24            15            11           14.83          4.30
# 10            23            14            12           19.50          6.37
# 11            14            17            13           13.50          3.59
# 12            16            13            14           19.83          5.64
# 13            20            23            15           16.00          5.54
# 14            17            16            16           20.67          9.59
# 15            15            19            17           17.33          5.12
# 16            19            10            18           15.67          6.45
# 17             7            12            19            9.33          5.06
# 18            27            21            20           16.33          8.67
# 19            34            29            21           33.67          8.67
#
#     CIMI 2014  CIMI 2015  CIMI 2016  CIMI 2017  CIMI 2018  CIMI 2019  \
# 0      100.00      99.65      98.71      99.27     100.00     100.00
# 1       92.24     100.00     100.00     100.00      94.63      95.73
# 2       87.69      92.89      91.97      90.20      86.23      85.50
# 3       84.15      85.12      84.85      84.38      84.11      81.95
# 4       80.48      86.00      77.56      74.55      81.80      78.51
# 5       78.06      84.72      83.40      76.34      80.88      77.46
# 6       85.05      90.32      82.86      77.44      86.70      77.31
# 7       83.37      82.80      79.22      79.52      82.73      76.71
# 8       80.40      77.20      71.69      77.48      78.76      76.04
# 9       81.43      85.11      82.51      68.04      76.66      75.96
# 10      80.64      80.37      77.75      68.14      77.45      75.79
# 11      80.24      90.23      82.55      73.55      75.55      75.04
# 12      78.12      80.66      77.76      73.29      77.89      75.00
# 13      79.24      85.12      86.10      70.31      73.14      74.32
# 14      72.29      84.72      80.82      72.80      76.04      74.10
# 15      77.69      86.06      81.14      73.50      75.26      74.07
# 16      84.78      82.00      81.94      71.51      78.85      73.84
# 17      88.47      89.60      84.91      79.21      78.13      73.67
# 18      79.03      92.41      88.46      67.31      75.07      72.40
# 19      75.50      75.24      70.13      64.88      70.39      72.22
#
#     average_CIMI      performance
# 0          99.60             High
# 1          97.10             High
# 2          89.08  Relatively High
# 3          84.09  Relatively High
# 4          79.82  Relatively High
# 5          80.14  Relatively High
# 6          83.28  Relatively High
# 7          80.73  Relatively High
# 8          76.93  Relatively High
# 9          78.28  Relatively High
# 10         76.69  Relatively High
# 11         79.53  Relatively High
# 12         77.12  Relatively High
# 13         78.04  Relatively High
# 14         76.80  Relatively High
# 15         77.95  Relatively High
# 16         78.82  Relatively High
# 17         82.33  Relatively High
# 18         79.11  Relatively High
# 19         71.39  Relatively High

# %%
# Оставляем только город, страну и категорию рейтинга в "узком" списке
r1_2_perf = pd.concat([r1_2['City'], r1_2['Country'], pd.Series(r1_2.apply(perf, axis=1), name = 'performance')], axis=1)
r1_2_perf.head(10)
# Out:
#             City         Country      performance
# 0         London  United Kingdom             High
# 1  New York City   United States             High
# 2          Paris          France  Relatively High
# 3          Tokyo           Japan  Relatively High
# 4     Copenhagen         Denmark  Relatively High
# 5         Berlin         Germany  Relatively High
# 6      Amsterdam     Netherlands  Relatively High
# 7      Singapore       Singapore  Relatively High
# 8      Hong Kong           China  Relatively High
# 9         Zurich     Switzerland  Relatively High

# %%
r1_2_perf_count = r1_2_perf['performance'].value_counts()
# r1_2_perf_count['2'] = r1_2_perf['performance'].value_counts(normalize=True) Показывает доли значений по категориям.
r1_2_perf_count
# Out:
# Relatively High    68
# Medium             31
# Low                18
# High                2
# Name: performance, dtype: int64

# %%
r1_2_perf_count.plot(kind='pie', autopct='%1.0f%%', shadow=True, explode=(0.1, 0.1, 0.1, 0.1))
plt.title("Уровни эффективности умных городов по среднему индексу с 2014 по 2019 гг.")
# Out:
# Text(0.5, 1.0, 'Уровни эффективности умных городов по среднему индексу с 2014 по 2019 гг.')

# %% [markdown]
# Формируем "широкий" список - все города, попадавшие в рейтинг за шесть лет.

# %%
rank_2014_2019_outer = rank_2014.merge(rank_2015, how = 'outer', on = ['City', 'Country']).merge(rank_2016, 
                how = 'outer', on = ['City', 'Country']).merge(rank_2017, 
                how = 'outer', on = ['City', 'Country']).merge(rank_2018, 
                how = 'outer', on = ['City', 'Country']).merge(rank_2019, 
                how = 'outer', on = ['City', 'Country'])
rank_2014_2019_outer.loc[:,['City', 'Country', 'Ranking 2014', 'Ranking 2015', 'Ranking 2016', 
                           'Ranking 2017', 'Ranking 2018', 'Ranking 2019']].sort_values(by='Ranking 2019', ascending=True)
# Out:
#               City         Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# 0           London  United Kingdom           1.0           2.0           2.0
# 1    New York City   United States           2.0           1.0           1.0
# 3            Paris          France           4.0           3.0           3.0
# 6            Tokyo           Japan           7.0          12.0           8.0
# 184      Reykjavik         Iceland           NaN           NaN           NaN
# ..             ...             ...           ...           ...           ...
# 169         Skopje       Macedonia           NaN         146.0         142.0
# 177         Bombay           India           NaN         167.0           NaN
# 180         Tehran            Iran           NaN         177.0         161.0
# 194     Valladolid           Spain           NaN           NaN           NaN
# 195           Vigo           Spain           NaN           NaN           NaN
#
#      Ranking 2017  Ranking 2018  Ranking 2019
# 0             2.0           1.0           1.0
# 1             1.0           2.0           2.0
# 3             3.0           4.0           3.0
# 6             4.0           6.0           4.0
# 184           5.0           5.0           5.0
# ..            ...           ...           ...
# 169         125.0           NaN           NaN
# 177           NaN           NaN           NaN
# 180           NaN           NaN           NaN
# 194          99.0           NaN           NaN
# 195         104.0           NaN           NaN
#
# [206 rows x 8 columns]

# %% [markdown]
# Вариант 1 получения среднего места и среднего рейтинга по "широкому" списку.
# Будем присваивать вместо NaN макс. рейтинг года+1, далее считать средний рейтинг на расширенную выборку и смотреть разбросы между годами и между средним рейтингом.

# %%
# rank_2014_2019_outer['Ranking 2014'].fillna(np.max(rank_2014_2019_outer['Ranking 2014']) + 1, inplace = True)
# rank_2014_2019_outer['Ranking 2015'].fillna(np.max(rank_2014_2019_outer['Ranking 2015']) + 1, inplace = True)
# rank_2014_2019_outer['Ranking 2016'].fillna(np.max(rank_2014_2019_outer['Ranking 2016']) + 1, inplace = True)
# rank_2014_2019_outer['Ranking 2017'].fillna(np.max(rank_2014_2019_outer['Ranking 2017']) + 1, inplace = True)
# rank_2014_2019_outer['Ranking 2018'].fillna(np.max(rank_2014_2019_outer['Ranking 2018']) + 1, inplace = True)
# rank_2014_2019_outer['Ranking 2019'].fillna(np.max(rank_2014_2019_outer['Ranking 2019']) + 1, inplace = True)
# Если поставить inplace = True, то перезапишется сразу исходный датафрейм. Мне так не надо.
r1_outer = rank_2014_2019_outer.loc[:,['City', 'Country']]
r1_outer['Ranking 2014'] = rank_2014_2019_outer['Ranking 2014'].fillna(np.max(rank_2014_2019_outer['Ranking 2014']) + 1, inplace = False)
r1_outer['Ranking 2015'] = rank_2014_2019_outer['Ranking 2015'].fillna(np.max(rank_2014_2019_outer['Ranking 2015']) + 1, inplace = False)
r1_outer['Ranking 2016'] = rank_2014_2019_outer['Ranking 2016'].fillna(np.max(rank_2014_2019_outer['Ranking 2016']) + 1, inplace = False)
r1_outer['Ranking 2017'] = rank_2014_2019_outer['Ranking 2017'].fillna(np.max(rank_2014_2019_outer['Ranking 2017']) + 1, inplace = False)
r1_outer['Ranking 2018'] = rank_2014_2019_outer['Ranking 2018'].fillna(np.max(rank_2014_2019_outer['Ranking 2018']) + 1, inplace = False)
r1_outer['Ranking 2019'] = rank_2014_2019_outer['Ranking 2019'].fillna(np.max(rank_2014_2019_outer['Ranking 2019']) + 1, inplace = False)
r1_outer['average_rating_extra'] = r1_outer[['Ranking 2014', 'Ranking 2015', 'Ranking 2016', 
                            'Ranking 2017', 'Ranking 2018', 'Ranking 2019']].mean(axis=1).round(2)
r1_outer['rank_extra'] = r1_outer['average_rating_extra'].rank(method = 'first')
r1_outer['rank_extra'] = pd.to_numeric(r1_outer['rank_extra'], downcast = 'integer')
r1_outer.sort_values(by='rank_extra', ascending=True).iloc[50:70]
# Out:
#           City               Country  Ranking 2014  Ranking 2015  \
# 45       Osaka                 Japan          46.0          56.0
# 46   Eindhoven           Netherlands          47.0          59.0
# 72    Valencia                 Spain          73.0          49.0
# 71      Warsaw                Poland          72.0          74.0
# 19   Liverpool        United Kingdom          20.0          48.0
# 43        Linz               Austria          44.0          63.0
# 148  Baltimore         United States         149.0          18.0
# 64    Budapest               Hungary          65.0          68.0
# 67        Rome                 Italy          68.0          81.0
# 29       Dubai  United Arab Emirates          30.0          65.0
# 152  Rotterdam           Netherlands         149.0          70.0
# 73      Taipei                Taiwan          74.0          64.0
# 150    Tallinn               Estonia         149.0          54.0
# 82    Shanghai                 China          83.0          93.0
# 44       Leeds        United Kingdom          45.0          71.0
# 79      Malaga                 Spain          80.0          58.0
# 65        Nice                France          66.0          61.0
# 76        Riga                Latvia          77.0          78.0
# 78     Seville                 Spain          79.0          67.0
# 31    Tel Aviv                Israel          32.0          97.0
#
#      Ranking 2016  Ranking 2017  Ranking 2018  Ranking 2019  \
# 45           72.0          56.0          68.0          64.0
# 46           58.0          65.0          57.0          77.0
# 72           63.0          63.0          61.0          60.0
# 71           54.0          64.0          69.0          54.0
# 19           55.0          82.0          94.0          94.0
# 43           46.0          73.0          87.0          80.0
# 148          20.0          77.0          71.0          61.0
# 64           67.0          53.0          73.0          74.0
# 67           43.0          66.0          75.0          67.0
# 29           66.0          60.0          99.0          92.0
# 152          59.0          43.0          43.0          51.0
# 73           56.0         166.0          30.0          27.0
# 150          53.0          50.0          65.0          55.0
# 82           80.0          57.0          59.0          58.0
# 44           76.0          81.0          79.0          79.0
# 79           51.0          89.0          80.0          82.0
# 65           74.0          79.0          85.0          83.0
# 76           82.0          49.0          84.0          85.0
# 78           68.0          85.0          76.0          81.0
# 31          106.0          72.0          81.0          70.0
#
#      average_rating_extra  rank_extra
# 45                  60.33          51
# 46                  60.50          52
# 72                  61.50          53
# 71                  64.50          54
# 19                  65.50          55
# 43                  65.50          56
# 148                 66.00          57
# 64                  66.67          58
# 67                  66.67          59
# 29                  68.67          60
# 152                 69.17          61
# 73                  69.50          62
# 150                 71.00          63
# 82                  71.67          64
# 44                  71.83          65
# 79                  73.33          66
# 65                  74.67          67
# 76                  75.83          68
# 78                  76.00          69
# 31                  76.33          70

# %%
# Посмотрим разброс рейтингов - стандартное отклонение
r1_outer['stdev_rating_extra'] = np.std(r1_outer[['Ranking 2014', 'Ranking 2015', 'Ranking 2016', 
                           'Ranking 2017', 'Ranking 2018', 'Ranking 2019']], axis=1).round(2)
r1_outer
# Out:
#               City          Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# 0           London   United Kingdom           1.0           2.0           2.0
# 1    New York City    United States           2.0           1.0           1.0
# 2            Seoul      South Korea           3.0           8.0           7.0
# 3            Paris           France           4.0           3.0           3.0
# 4        Amsterdam      Netherlands           5.0           6.0          10.0
# ..             ...              ...           ...           ...           ...
# 201        Seattle    United States         149.0         182.0         181.0
# 202    Quebec City           Canada         149.0         182.0         181.0
# 203       Asuncion         Paraguay         149.0         182.0         181.0
# 204         Skopje  North Macedonia         149.0         182.0         181.0
# 205         Lahore         Pakistan         149.0         182.0         181.0
#
#      Ranking 2017  Ranking 2018  Ranking 2019  average_rating_extra  \
# 0             2.0           1.0           1.0                  1.50
# 1             1.0           2.0           2.0                  1.50
# 2             7.0          12.0          19.0                  9.33
# 3             3.0           4.0           3.0                  3.33
# 4            10.0           3.0           8.0                  7.00
# ..            ...           ...           ...                   ...
# 201         166.0          58.0          53.0                131.50
# 202         166.0          67.0          89.0                139.00
# 203         166.0         141.0         131.0                158.33
# 204         166.0         149.0         141.0                161.33
# 205         166.0         173.0         172.0                170.50
#
#      rank_extra  stdev_rating_extra
# 0             1                0.50
# 1             2                0.50
# 2             6                5.06
# 3             3                0.47
# 4             5                2.58
# ..          ...                 ...
# 201         135               54.87
# 202         147               44.96
# 203         182               19.44
# 204         190               16.09
# 205         206               11.06
#
# [206 rows x 11 columns]

# %%
r1_outer['stdev_rating_extra'].mean()
# Получили среднее значение стандартных отклонений по "широкому" списку рейтингов
# Out:
# 17.37271844660194

# %%
r1_outer_stdev_less10 = r1_outer[r1_outer['stdev_rating_extra'] < 10]
r1_outer_stdev_less10['stdev_rating_extra'].count()
r1_outer['stdev_rating_extra'].count()
round(r1_outer_stdev_less10['stdev_rating_extra'].count()/r1_outer['stdev_rating_extra'].count()*100, 2)
# Получили процент городов, у которых по широкому списку №1 станд. отклонения рейтинга менее 10 
# Это те, кто стабильно держат свои места все шесть лет. Такие города есть на всем протяжении списка.
# Out:
# 36.89

# %%
# Строим график рассеяния между средним и стандартным отклонением. 
# Появляется большой разброс для рейтиноговых с 70 до 155, остальное - нормально
r1_outer.plot(kind='scatter', 
        x='average_rating_extra', 
        y='stdev_rating_extra' 
        )
plt.title('Широкий список рейтингов №1, со штрафом, за 2014-2019 гг.')
plt.show()

# %%
# График распределения стандартных отклонений - НЕ нормальный.
# r1['stdev_rating'].plot.hist()
sns.histplot(data=r1_outer['stdev_rating_extra'], kde=True)
# Out:
# <AxesSubplot:xlabel='stdev_rating_extra', ylabel='Count'>

# %%
# Добавляем ранжирование "узкого" списка. r1 - несортированный список
r1['rank'] = r1['average_rating'].rank(method = 'first')
r1['rank'] = pd.to_numeric(r1['rank'], downcast = 'integer') #Переводим ранг в целое число
r1['avg_rating-rank'] = r1['average_rating']-r1['rank']
r1_sorted_by_rank = r1.sort_values(by='rank', ascending = True)
# r1_sorted_by_rank.iloc[42:82]
r1_sorted_by_rank.iloc[82:120]
# Смотрим на разные зоны по местам - где начинается сильное отставание
# Out:
#                City                 Country  Ranking 2014  Ranking 2015  \
# 78            Sofia                Bulgaria            85            95
# 84           Athens                  Greece            92           113
# 97       Montevideo                 Uruguay           109           121
# 86           Naples                   Italy            96            90
# 54        Jerusalem                  Israel            58           105
# 92        Guangzhou                   China           104           104
# 85      Mexico City                  Mexico            95           100
# 75         Istanbul                  Turkey            82           109
# 87           Bogota                Colombia            97           111
# 95         Medellín                Colombia           107            99
# 90        São Paulo                  Brasil           102           124
# 104        Shenzhen                   China           118           130
# 89             Doha                   Qatar           100           117
# 102   St Petersburg                  Russia           115           133
# 94          Cordoba               Argentina           106           106
# 91             Lima                    Peru           103           122
# 110  Rio de Janeiro                  Brasil           133           139
# 96           Ankara                  Turkey           108           127
# 101         Rosario               Argentina           114           134
# 99         Curitiba                  Brasil           111           129
# 98             Cali                Colombia           110           126
# 100        Brasilia                  Brasil           112           136
# 106           Quito                 Ecuador           121           132
# 103       Cape Town            South Africa           117           120
# 105        Sarajevo  Bosnia and Herzegovina           120           157
# 93           Riyadh            Saudi Arabia           105           123
# 107         Jakarta               Indonesia           123           170
# 111        Salvador                  Brasil           134           151
# 108          Manila             Philippines           127           145
# 109    Johannesburg            South Africa           130           140
# 114  Belo Horizonte                  Brasil           139           152
# 116   Santo Domingo      Dominican Republic           145           172
# 112         Tianjin                   China           135           166
# 115          La Paz                 Bolivia           144           168
# 113           Cairo                   Egypt           137           156
# 117         Caracas               Venezuela           147           162
# 118        Calcutta                   India           148           179
#
#      Ranking 2016  Ranking 2017  Ranking 2018  Ranking 2019  average_rating  \
# 78             91           101           115           116          100.50
# 84             94           122           106            96          103.83
# 97             99           100            92           110          105.17
# 86             93           119           116           119          105.50
# 54            108           121           123           121          106.00
# 92            102           109           113           107          106.50
# 85             87           107           133           130          108.67
# 75            104           114           118           129          109.33
# 87            113           117           117           120          112.50
# 95             96           129           134           126          115.17
# 90            101           116           132           123          116.33
# 104           118           115           119           109          118.17
# 89            132           111           126           125          118.50
# 102           103           123           121           124          119.83
# 94            107           133           136           139          121.17
# 91            116           131           138           155          127.50
# 110           114           126           128           132          128.67
# 96            147           120           135           136          128.83
# 101           139           130           125           134          129.33
# 99            131           135           140           138          130.67
# 98            122           137           148           145          131.33
# 100           143           138           130           135          132.33
# 106           130           140           137           142          133.67
# 103           133           143           158           143          135.67
# 105           134           132           144           153          140.00
# 93            138           153           164           167          141.67
# 107           156           136           142           133          143.33
# 111           135           147           146           157          145.00
# 108           148           146           163           165          149.00
# 109           155           156           167           151          149.83
# 114           153           151           151           156          150.33
# 116           169           154           139           137          152.67
# 112           164           149           154           148          152.67
# 115           170           152           145           147          154.33
# 113           163           157           165           168          157.67
# 117           173           162           172           174          165.00
# 118           178           163           169           169          167.67
#
#      stdev_rating  rank  avg_rating-rank
# 78          11.63    83            17.50
# 84          10.93    84            19.83
# 97           9.37    85            20.17
# 86          12.66    86            19.50
# 54          22.54    87            19.00
# 92           3.69    88            18.50
# 85          17.23    89            19.67
# 75          14.49    90            19.33
# 87           7.52    91            21.50
# 95          15.05    92            23.17
# 90          11.47    93            23.33
# 104          6.26    94            24.17
# 89          10.66    95            23.50
# 102          9.21    96            23.83
# 94          14.94    97            24.17
# 91          16.54    98            29.50
# 110          7.74    99            29.67
# 96          12.48   100            28.83
# 101          8.08   101            28.33
# 99           9.57   102            28.67
# 98          13.34   103            28.33
# 100          9.88   104            28.33
# 106          7.04   105            28.67
# 103         14.19   106            29.67
# 105         12.74   107            33.00
# 93          22.27   108            33.67
# 107         15.53   109            34.33
# 111          8.23   110            35.00
# 108         12.66   111            38.00
# 109         11.91   112            37.83
# 114          5.34   113            37.33
# 116         13.74   114            38.67
# 112         10.45   115            37.67
# 115         10.69   116            38.33
# 113         10.16   117            40.67
# 117          9.45   118            47.00
# 118         10.39   119            48.67

# %%
r1_sorted_by_rank['avg_rating-rank'].iloc[0:42].agg(['mean', 'max'])
# Out:
# mean    2.519048
# max     5.670000
# Name: avg_rating-rank, dtype: float64

# %%
r1_sorted_by_rank['avg_rating-rank'].iloc[42:82].agg(['mean', 'min', 'max'])
# Out:
# mean     9.8415
# min      5.5000
# max     12.3300
# Name: avg_rating-rank, dtype: float64

# %%
r1['avg_rating-rank'].iloc[82:119].agg(['mean', 'max'])
# Out:
# mean    28.702973
# max     48.670000
# Name: avg_rating-rank, dtype: float64

# %%
y=r1_sorted_by_rank['avg_rating-rank']
x=np.arange(len(y))
plt.plot(x,y)
plt.grid(axis = 'y')
plt.ylabel("Ср. место в рейтинге \nминус ранг по ср. месту")
plt.xlabel("Ранг по ср. месту")
plt.title("Отклонения среднего места в рейтинге за шесть лет \nот места при повторном ранжировании по узкому списку")
# Показывает, что отклонения в топ-42 cтабильны (mean 2.519048, max 5.670000) - лидеры есть в рейтингах всех лет,
# место лидеров по годам может колебаться, но в рейтинге по среднему месту они остаются примерно той же позиции/месте.
# В списке от 42 до 82 места по рангу среднего места, отклонения ранга от среднего места в среднем 10, 
# т.е. 1) либо эти города могут сильно сдавать свои позиции в отдельные годы, 
# 2) либо в отдельные годы их оттестяли другие города, которые участвовали не во всех рейтингах (похоже, это чаще встречается)
# Out:
# Text(0.5, 1.0, 'Отклонения среднего места в рейтинге за шесть лет \nот места при повторном ранжировании по узкому списку')

# %%
y=r1_sorted_by_rank['avg_rating-rank']
x_s=r1_sorted_by_rank['stdev_rating']
plt.scatter(x_s,y)
plt.grid(axis = 'y')
# Показывает, что нет связи между станд. отклонением мест по годам и 
# "разбегом" между рангом по среднему месту и средним местом за 6 лет
# Т.е. имеют место оба случая 1 и 2 описанных выше (за счет колебания мест и за счет новых участников)

# %%
r1_sorted_by_rank[['stdev_rating', 'avg_rating-rank']].corr()
# Нет корреляции (см. выше)
# Out:
#                  stdev_rating  avg_rating-rank
# stdev_rating         1.000000         0.276778
# avg_rating-rank      0.276778         1.000000

# %%
# Объединяем "узкий" и "широкий" рейтинги
rank_matching_1 = r1.merge(r1_outer, how = 'inner', on = ['City', 'Country'])
rank_matching_1.loc[:,['City', 'Country', 'rank', 
                     'rank_extra']].sort_values(by='rank_extra', ascending=True)
# Out:
#               City             Country  rank  rank_extra
# 0           London      United Kingdom     1           1
# 1    New York City       United States     2           2
# 2            Paris              France     3           3
# 3            Tokyo               Japan     4           4
# 6        Amsterdam         Netherlands     5           5
# ..             ...                 ...   ...         ...
# 101  Santo Domingo  Dominican Republic   114         167
# 107         La Paz             Bolivia   116         171
# 116          Cairo               Egypt   117         179
# 118        Caracas           Venezuela   118         195
# 117       Calcutta               India   119         202
#
# [119 rows x 4 columns]

# %%
rank_matching_1.plot(kind='scatter', 
        x='rank', 
        y='rank_extra' 
        )
x1,x2,y1,y2 = plt.axis()
# plt.axis((0,50,0,50)) # Топ-50 городов попадали в рейтинги во все годы
# plt.axis((50,80,50,90)) # Тут уже попадаются города, которых не было в некоторых рейтингах, но при этом, они сохраняют довольно высокую позицию в расширенном рейтинге
# plt.axis((80,100,80,130)) # Таких городов все больше, т.е. мы допускаем к рассмотрению все города, которые хотя бы когда-то участвовали. 
plt.axis((100,120,120,200)) # Ценность места 90-110 в узком рейтинге такая же, как места 120-200 в широком рейтинге. 
# Дополнительные участники попадали во все зоны мест, причем больше во вторую половину, за счет этого отрыв в порядковом номере рейтинга все больше увеличивался по мере приближения к концу списка.
plt.show()

# %% [markdown]
# Посмотрим, на сколько отличаются рейтинговые места для узкого и широкого списка

# %%
rank_matching_1['rank_difference'] = rank_matching_1['rank_extra'] - rank_matching_1['rank']
rank_matching_1['rank_difference'].plot()
plt.grid(axis = 'y')
# Выше сравнивала разницу между средним местом за шесть лет и рейтингом по "узкому" списку
# Здесь сравниваю разницу между рейтингами по "широкому" и "узкому" списку. 
# Здесь картина такая же - первые 40 позиций практически не меняют своих мест, 
# с 40 по 70 увеличивают место не более чем на 10 позиций,
# с 70 по 100 позиции прирост места растет до 20 позиций,
# далее видно, что участники из нижней части "узкого" списка очень сильно могут ухудшать свою позицию в "широком" списке - 
# до 80 позиций в ухудшение, т.е. это реально "слабые" города

# %%
rank_matching_1.plot(kind='scatter', 
        x='rank', 
        y='rank_difference' 
        )
# Out:
# <AxesSubplot:xlabel='rank', ylabel='rank_difference'>

# %%
rank_matching_1.plot(kind='scatter', 
        x='rank_extra', 
        y='rank_difference' 
        )
# Out:
# <AxesSubplot:xlabel='rank_extra', ylabel='rank_difference'>

# %% [markdown]
# Нужно попробовать 2 вариант усреднения места в "широком" списке, как место в рейтинге равно среднему месту только за те годы, в которых участвовал город, без присвоения штрафов. Т.е. если участвовал в трех рейтингах, то среднее по трем значениям.

# %%
rank_2014_2019_outer
# Out:
#      Ranking 2014           City          Country  CIMI 2014  Ranking 2015  \
# 0             1.0         London   United Kingdom     100.00           2.0
# 1             2.0  New York City    United States      92.24           1.0
# 2             3.0          Seoul      South Korea      88.47           8.0
# 3             4.0          Paris           France      87.69           3.0
# 4             5.0      Amsterdam      Netherlands      85.05           6.0
# ..            ...            ...              ...        ...           ...
# 201           NaN        Seattle    United States        NaN           NaN
# 202           NaN    Quebec City           Canada        NaN           NaN
# 203           NaN       Asuncion         Paraguay        NaN           NaN
# 204           NaN         Skopje  North Macedonia        NaN           NaN
# 205           NaN         Lahore         Pakistan        NaN           NaN
#
#      CIMI 2015  Ranking 2016  CIMI 2016  Ranking 2017  CIMI 2017  \
# 0        99.65           2.0      98.71           2.0      99.27
# 1       100.00           1.0     100.00           1.0     100.00
# 2        89.60           7.0      84.91           7.0      79.21
# 3        92.89           3.0      91.97           3.0      90.20
# 4        90.32          10.0      82.86          10.0      77.44
# ..         ...           ...        ...           ...        ...
# 201        NaN           NaN        NaN           NaN        NaN
# 202        NaN           NaN        NaN           NaN        NaN
# 203        NaN           NaN        NaN           NaN        NaN
# 204        NaN           NaN        NaN           NaN        NaN
# 205        NaN           NaN        NaN           NaN        NaN
#
#      Ranking 2018  CIMI 2018  Ranking 2019  CIMI 2019
# 0             1.0     100.00           1.0     100.00
# 1             2.0      94.63           2.0      95.73
# 2            12.0      78.13          19.0      73.67
# 3             4.0      86.23           3.0      85.50
# 4             3.0      86.70           8.0      77.31
# ..            ...        ...           ...        ...
# 201          58.0      61.96          53.0      63.32
# 202          67.0      60.64          89.0      54.90
# 203         141.0      37.25         131.0      42.34
# 204         149.0      33.88         141.0      38.15
# 205         173.0       6.27         172.0      13.76
#
# [206 rows x 14 columns]

# %%
r2_outer = rank_2014_2019_outer.loc[:,['City', 'Country']]
r2_outer['Ranking 2014'] = rank_2014_2019_outer['Ranking 2014'].fillna(0, inplace = False)
r2_outer['Ranking 2015'] = rank_2014_2019_outer['Ranking 2015'].fillna(0, inplace = False)
r2_outer['Ranking 2016'] = rank_2014_2019_outer['Ranking 2016'].fillna(0, inplace = False)
r2_outer['Ranking 2017'] = rank_2014_2019_outer['Ranking 2017'].fillna(0, inplace = False)
r2_outer['Ranking 2018'] = rank_2014_2019_outer['Ranking 2018'].fillna(0, inplace = False)
r2_outer['Ranking 2019'] = rank_2014_2019_outer['Ranking 2019'].fillna(0, inplace = False)
r2_outer['average_rating_notNone'] = (r2_outer[['Ranking 2014', 'Ranking 2015', 'Ranking 2016', 
                           'Ranking 2017', 'Ranking 2018', 'Ranking 2019']].sum(
                            axis=1)/(np.count_nonzero(r2_outer, axis=1)-2)).round(1)
r2_outer['rank_notNone'] = r2_outer['average_rating_notNone'].rank(method = 'first')
r2_outer['rank_notNone'] = pd.to_numeric(r2_outer['rank_notNone'], downcast = 'integer')
r2_outer.sort_values(by='rank_notNone', ascending=True).iloc[20:40]
# Вывели рейтинг №2 "широкого" списка
# Out:
#             City        Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# 41   Los Angeles  United States          42.0          15.0          18.0
# 35       Toronto         Canada          36.0          24.0          11.0
# 16     Hong Kong          China          17.0          39.0          42.0
# 7         Geneva    Switzerland           8.0           9.0          17.0
# 12      Helsinki        Finland          13.0          25.0          29.0
# 185   Wellington    New Zealand           0.0           0.0           0.0
# 9         Munich        Germany          10.0          21.0          19.0
# 34        Madrid          Spain          35.0          34.0          28.0
# 33     Barcelona          Spain          34.0          33.0          35.0
# 186         Bern    Switzerland           0.0           0.0           0.0
# 21        Dublin        Ireland          22.0          36.0          33.0
# 28         Basel    Switzerland          29.0          42.0          47.0
# 27     Frankfurt        Germany          28.0          35.0          36.0
# 36       Hamburg        Germany          37.0          41.0          34.0
# 40        Dallas  United States          41.0          19.0          23.0
# 37      Auckland    New Zealand          38.0          29.0          44.0
# 48        Ottawa         Canada          49.0          30.0          24.0
# 149       London         Canada           0.0          37.0           0.0
# 52     Vancouver         Canada          53.0          20.0          21.0
# 51      Montreal         Canada          52.0          38.0          31.0
#
#      Ranking 2017  Ranking 2018  Ranking 2019  average_rating_notNone  \
# 41           17.0          16.0          16.0                    20.7
# 35            8.0          18.0          30.0                    21.2
# 16            9.0          11.0          10.0                    21.3
# 7            32.0          32.0          34.0                    22.0
# 12           22.0          22.0          22.0                    22.2
# 185          18.0          26.0          23.0                    22.3
# 9            37.0          27.0          24.0                    23.0
# 34           25.0          24.0          25.0                    28.5
# 33           26.0          28.0          26.0                    30.3
# 186          29.0          31.0          31.0                    30.3
# 21           30.0          37.0          33.0                    31.8
# 28           34.0          29.0          21.0                    33.7
# 27           42.0          33.0          32.0                    34.3
# 36           31.0          34.0          29.0                    34.3
# 40           41.0          45.0          38.0                    34.5
# 37           28.0          35.0          35.0                    34.8
# 48           35.0          39.0          43.0                    36.7
# 149           0.0           0.0           0.0                    37.0
# 52           36.0          55.0          44.0                    38.2
# 51           38.0          38.0          40.0                    39.5
#
#      rank_notNone
# 41             21
# 35             22
# 16             23
# 7              24
# 12             25
# 185            26
# 9              27
# 34             28
# 33             29
# 186            30
# 21             31
# 28             32
# 27             33
# 36             34
# 40             35
# 37             36
# 48             37
# 149            38
# 52             39
# 51             40

# %%
# Снова посмотрим разброс рейтингов - стандартное отклонение
r2_outer['stdev_rating_notNone'] = np.std(r2_outer[['Ranking 2014', 'Ranking 2015', 'Ranking 2016', 
                           'Ranking 2017', 'Ranking 2018', 'Ranking 2019']], axis=1).round(2)
r2_outer
# Out:
#               City          Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# 0           London   United Kingdom           1.0           2.0           2.0
# 1    New York City    United States           2.0           1.0           1.0
# 2            Seoul      South Korea           3.0           8.0           7.0
# 3            Paris           France           4.0           3.0           3.0
# 4        Amsterdam      Netherlands           5.0           6.0          10.0
# ..             ...              ...           ...           ...           ...
# 201        Seattle    United States           0.0           0.0           0.0
# 202    Quebec City           Canada           0.0           0.0           0.0
# 203       Asuncion         Paraguay           0.0           0.0           0.0
# 204         Skopje  North Macedonia           0.0           0.0           0.0
# 205         Lahore         Pakistan           0.0           0.0           0.0
#
#      Ranking 2017  Ranking 2018  Ranking 2019  average_rating_notNone  \
# 0             2.0           1.0           1.0                     1.5
# 1             1.0           2.0           2.0                     1.5
# 2             7.0          12.0          19.0                     9.3
# 3             3.0           4.0           3.0                     3.3
# 4            10.0           3.0           8.0                     7.0
# ..            ...           ...           ...                     ...
# 201           0.0          58.0          53.0                    55.5
# 202           0.0          67.0          89.0                    78.0
# 203           0.0         141.0         131.0                   136.0
# 204           0.0         149.0         141.0                   145.0
# 205           0.0         173.0         172.0                   172.5
#
#      rank_notNone  stdev_rating_notNone
# 0               1                  0.50
# 1               2                  0.50
# 2               7                  5.06
# 3               3                  0.47
# 4               6                  2.58
# ..            ...                   ...
# 201            64                 26.20
# 202            90                 37.31
# 203           159                 64.18
# 204           173                 68.39
# 205           204                 81.32
#
# [206 rows x 11 columns]

# %%
r2_outer['stdev_rating_notNone'].mean()
# Получили среднее значение стандартных отклонений по "широкому" списку №2 рейтингов. 
# Здесь станд. отклонение учитывает нулевые значения, а значит сильно увеличивается размах отклонений.
# В широком списке №1 в усреднении участвовали последнее +1 места, в широком списке №2 - нулевые места. 
# Нулевого места в принципе не может быть, так что показатель станд. отклонения пользоваться для сравнения списков не будем.
# Out:
# 26.9681067961165

# %%
r2_outer_stdev_less10 = r2_outer[r2_outer['stdev_rating_notNone'] < 10]
r2_outer_stdev_less10['stdev_rating_notNone'].count()
r2_outer['stdev_rating_notNone'].count()
round(r2_outer_stdev_less10['stdev_rating_notNone'].count()/r2_outer['stdev_rating_notNone'].count()*100, 2)
# Получили процент городов, у которых по широкому списку №1 станд. отклонения рейтинга менее 10 
# Это те, кто стабильно держат свои места все шесть лет. Такие города есть на всем протяжении списка.
# Out:
# 32.04

# %%
# Строим график рассеяния между средним и стандартным отклонением для широкого списка №2
r2_outer.plot(kind='scatter', 
        x='average_rating_notNone', 
        y='stdev_rating_notNone' 
        )
plt.title('Широкий список рейтингов №2, без штрафов, за 2014-2019 гг.')
plt.show()
# Формула стандартного отклонения не подходит для данного вида широкого списка, т.к. усредняет с нулевым (пустым) значением

# %%
# График распределения стандартных отклонений - НЕ нормальный. 
# Первые два значения станд. отклонений 0-10, 10-20 встречаются чаще и в сумме дают примерно 119 значений узкого списка.
# В узком списке 90% станд. отклонений укладывались в 20.
# Про частоту остальных значений станд. отклонений (больше 20) можно сказать, что их распределение случайно.
sns.histplot(data=r2_outer['stdev_rating_notNone'], kde=True)
# Out:
# <AxesSubplot:xlabel='stdev_rating_notNone', ylabel='Count'>

# %% [markdown]
# Объединим из трех таблиц: из узкого списка городов (119) и двух видов широких списков городов (206) берем средние значения мест за шесть лет и вторичные рейтинги (рейтинги по средним местам).

# %%
rank_matching_2 = r1.merge(r1_outer, how = 'inner', on = ['City', 'Country']).merge(
    r2_outer, how = 'inner', on = ['City', 'Country'])
rank_matching_2_sorted_by_rank = rank_matching_2.loc[:,['City', 'Country', 'average_rating',  
                       'rank', 'rank_extra', 'rank_notNone']].sort_values(by='rank', ascending = True)
rank_matching_2_sorted_by_rank
# rank_matching_2_sorted_by_rank.iloc[30:50] Либо весь список, либо отрезок
# Получили список из 119 городов, у которых разные рейтинги по разным методам.
# Out:
#               City         Country  average_rating  rank  rank_extra  \
# 0           London  United Kingdom            1.50     1           1
# 1    New York City   United States            1.50     2           2
# 2            Paris          France            3.33     3           3
# 3            Tokyo           Japan            6.83     4           4
# 6        Amsterdam     Netherlands            7.00     5           5
# ..             ...             ...             ...   ...         ...
# 108        Tianjin           China          152.67   115         166
# 107         La Paz         Bolivia          154.33   116         171
# 116          Cairo           Egypt          157.67   117         179
# 118        Caracas       Venezuela          165.00   118         195
# 117       Calcutta           India          167.67   119         202
#
#      rank_notNone
# 0               1
# 1               2
# 2               3
# 3               5
# 6               6
# ..            ...
# 108           181
# 107           185
# 116           190
# 118           198
# 117           201
#
# [119 rows x 6 columns]

# %%
rank_matching_2_sorted_by_rank.corr()
# Out:
#                 average_rating      rank  rank_extra  rank_notNone
# average_rating        1.000000  0.994209    0.991612      0.999252
# rank                  0.994209  1.000000    0.976338      0.991922
# rank_extra            0.991612  0.976338    1.000000      0.994197
# rank_notNone          0.999252  0.991922    0.994197      1.000000

# %%
rank_matching_2.plot(kind='scatter', 
        x='rank_extra', 
        y='rank_notNone' 
        )
x1,x2,y1,y2 = plt.axis()
# plt.axis((0,50,0,60)) 
# plt.axis((50,80,60,100)) 
# plt.axis((80,100,100,120)) 
plt.axis((100,200,120,200)) 
# При таком способе усреднения (NaN = 0) среднее место в рейтинге увеличивается, т.к. на ранг влияет большое количество городов,
# которые попадали 1-2-3 раза в рейтинг и не были "оштрафованы" за неучастие в рейтинге прошлых лет. 
# Общее место города из числа середняков и аутсайдеров в таком списке увеличивается.
# Не понятно, какой способ усреднения результатов лучше. 
# Способ с NaN = 0 имеет право на рассмотрение, т.к. с годами появляются новые города в рейтинге, которые 
# отодвигают/побеждают прежних участников.
plt.show()

# %%
rank_matching_2.plot(kind='scatter', 
        x='rank', 
        y='rank_notNone' 
        )
x1,x2,y1,y2 = plt.axis()

# %%
# labels=rank_matching_2['City'].loc[30:50]
# y1=rank_matching_2['rank'].loc[30:50]
# y2=rank_matching_2['rank_extra'].loc[30:50] 
# y3=rank_matching_2['rank_notNone'].loc[30:50] 
# Можно так отсекать кусок данных для показа, либо через xlim (cм. ниже)

labels=rank_matching_2_sorted_by_rank['City']
y1=rank_matching_2_sorted_by_rank['rank']
y2=rank_matching_2_sorted_by_rank['rank_extra']
y3=rank_matching_2_sorted_by_rank['rank_notNone']

x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars

fig, ax = plt.subplots()

fig.set_figwidth(12) 

ax.bar(x-width, y1, width, label = 'Узкий список')
ax.bar(x, y2, width, label = 'Широкий список №1')
ax.bar(x+width, y3, width, label = 'Широкий список №2')

# x1,x2,y1,y2,y3,y4,y5,y6 = plt.axis() 
# plt.axis((30,50,10,100)) # Как настроить отсекание куска данных только для показа на графике?

ax.set_ylabel('Ranks')
ax.set_title('Ранги по разным способам получения средних рейтингов (часть списка)')
ax.set_xticks(x)
ax.set_xlim(50-0.5,70+0.5)
ax.set_ylim(40,90)
ax.set_xticklabels(labels, rotation = 90)
ax.legend()

# ax.bar_label(y1) #Не получились надписи

# for i in range(len(x)):
#     ax.annotate(str(y1[i]), xy=(x[i],y1[i]), ha='center', va='bottom', rotation=90) Не получились надписи

plt.show()

# %%
df2 = rank_matching_2[['City', 'average_rating', 'rank', 'rank_extra', 'rank_notNone']].sort_values(by='rank', 
                                                                  ascending = True).reset_index().drop(columns=['index'])
df2.plot.line(figsize=(10,5))
plt.title('Средний рейтинг по узкому списку и ранги по разным способам получения средних рейтингов')
# x1,x2,y1,y2 = plt.axis() Если хотим получить график по ограниченным значениям осей х и у
# plt.axis((0,40,0,50)) 
# Сортируем по какому-нибудь показателю, сбрасываем первоначальный индекс, и по новому индексу строим график
# Out:
# Text(0.5, 1.0, 'Средний рейтинг по узкому списку и ранги по разным способам получения средних рейтингов')

# %%
# Объединяем два широких списка со средними значениями и средними рейтингами
rank_matching_3 = r1_outer.merge(r2_outer, how = 'outer', on = ['City', 'Country'])
rank_matching_3_unsorted = rank_matching_3.loc[:,['City', 'Country', 'average_rating_extra',  
                       'average_rating_notNone', 'rank_extra', 'rank_notNone']]#.sort_values(by='rank_extra', ascending = True)
rank_matching_3_unsorted#.iloc[30:50]
# Получили список из 206 городов, у которых разные рейтинги по разным методам.
# Out:
#               City          Country  average_rating_extra  \
# 0           London   United Kingdom                  1.50
# 1    New York City    United States                  1.50
# 2            Seoul      South Korea                  9.33
# 3            Paris           France                  3.33
# 4        Amsterdam      Netherlands                  7.00
# ..             ...              ...                   ...
# 201        Seattle    United States                131.50
# 202    Quebec City           Canada                139.00
# 203       Asuncion         Paraguay                158.33
# 204         Skopje  North Macedonia                161.33
# 205         Lahore         Pakistan                170.50
#
#      average_rating_notNone  rank_extra  rank_notNone
# 0                       1.5           1             1
# 1                       1.5           2             2
# 2                       9.3           6             7
# 3                       3.3           3             3
# 4                       7.0           5             6
# ..                      ...         ...           ...
# 201                    55.5         135            64
# 202                    78.0         147            90
# 203                   136.0         182           159
# 204                   145.0         190           173
# 205                   172.5         206           204
#
# [206 rows x 6 columns]

# %%
rank_matching_3_unsorted.corr()
# Out:
#                         average_rating_extra  average_rating_notNone  \
# average_rating_extra                1.000000                0.907730
# average_rating_notNone              0.907730                1.000000
# rank_extra                          0.988584                0.907676
# rank_notNone                        0.906309                0.999277
#
#                         rank_extra  rank_notNone
# average_rating_extra      0.988584      0.906309
# average_rating_notNone    0.907676      0.999277
# rank_extra                1.000000      0.909170
# rank_notNone              0.909170      1.000000

# %%
df3 = rank_matching_3[['City', 'average_rating_extra', 'average_rating_notNone', 
                       'rank_extra', 'rank_notNone']].sort_values(by='rank_extra', 
                                                                  ascending = True).reset_index().drop(columns=['index'])
df3.plot.line(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
x = df3['City']
y1 = df3['average_rating_extra']
y2 = df3['rank_extra']
y3 = df3['average_rating_notNone']
y4 = df3['rank_notNone']

fig, (ax1, ax2) = plt.subplots(2, sharex=True)

ax1.plot(y1, color = 'r', label = "Среднее с штрафом") #y1.name)
ax1.plot(y2, color = 'b', label = "Рейтинг с штрафом") #y2.name)
ax2.plot(y3, label = "Среднее без штрафа") #y3.name)
ax2.plot(y4, label = "Рейтинг без штрафа") #y4.name)

ax1.legend()
ax2.legend()

ax1.set_title('"Широкий" список №1 с штрафом - если не попал в рейтинг года, занял последнее место')
ax2.set_title('"Широкий" список №2 без штрафа - если не попал в рейтинг года, не считается')

fig.set_figwidth(12)    #  ширина и высота
fig.set_figheight(6) 

plt.show()

# %%
df3.iloc[70:90]
# Хорошо видно, что в широком списке №2 "прорываются" в высокую часть рейтинга города, которых не было во всех шести годах.
# Например, Рейкьявик, который три последних года занимал 5 место, а ранее его не было. По второму списку он занимает 4 место,
# а по первому способу (со штрафами за неучастие) - 84 место. И в узком рейтинге его нет совсем.
# Случаи таких "прорывов" определим далее.
# Out:
#             City  average_rating_extra  average_rating_notNone  rank_extra  \
# 70      Florence                 77.50                    77.5          71
# 71    Nottingham                 77.83                    77.8          72
# 72     Marseille                 77.83                    77.8          73
# 73      Santiago                 78.50                    78.5          74
# 74         Lille                 81.83                    81.8          75
# 75  Buenos Aires                 83.67                    83.7          76
# 76      Duisburg                 84.50                    84.5          77
# 77       Antwerp                 84.67                    71.8          78
# 78    Bratislava                 84.67                    71.8          79
# 79     Ljubljana                 84.83                    84.8          80
# 80       Vilnius                 84.83                    72.0          81
# 81      A Coruña                 87.00                    87.0          82
# 82       Beijing                 87.67                    87.7          83
# 83     Reykjavik                 87.83                     5.0          84
# 84        Moscow                 88.33                    88.3          85
# 85         Porto                 89.00                    89.0          86
# 86        Bilbao                 89.67                    89.7          87
# 87         Turin                 90.17                    90.2          88
# 88        Nagoya                 90.83                    79.2          89
# 89       Bangkok                 93.33                    93.3          90
#
#     rank_notNone
# 70            87
# 71            88
# 72            89
# 73            91
# 74            93
# 75            94
# 76            95
# 77            79
# 78            80
# 79            96
# 80            81
# 81            99
# 82           100
# 83             4
# 84           101
# 85           102
# 86           103
# 87           104
# 88            92
# 89           108

# %%
rank_matching_3['rank_notNone_break'] = rank_matching_3['rank_notNone'] - rank_matching_3['rank_extra']
rank_matching_3_break = rank_matching_3[abs(rank_matching_3['rank_notNone_break']) > 30]
rank_matching_3_break = rank_matching_3_break.sort_values(by='rank_notNone_break', 
                                                              ascending = True).loc[:,['City', 'Country', 'average_rating_extra',  
                       'average_rating_notNone', 'rank_extra', 'rank_notNone', 
                        'rank_notNone_break']]
rank_matching_3_break
# Получили список "прорывных" городов, которые могут составлять конкуренцию
# Не очень интересно, когда эти изменения происходят во второй сотне списка. Это просто добавляются новые города в рейтинг
# Интересно, что появляются сильные участники в топ-70. И даже пример Рейкьявика в пятерке лидеров.
# Out:
#             City         Country  average_rating_extra  \
# 149       London          Canada                147.17
# 54     Abu Dhabi   Arab Emirates                155.67
# 184    Reykjavik         Iceland                 87.83
# 199   Düsseldorf         Germany                129.00
# 198    Edinburgh  United Kingdom                128.50
# 194   Valladolid           Spain                160.17
# 200       Denver   United States                131.50
# 201      Seattle   United States                131.50
# 195         Vigo           Spain                161.00
# 185   Wellington     New Zealand                 96.50
# 186         Bern     Switzerland                100.50
# 187     Göteborg          Sweden                105.17
# 202  Quebec City          Canada                139.00
# 188    San Diego   United States                108.83
# 160        Jidda    Saudi Arabia                160.17
# 115       Jeddah    Saudi Arabia                155.67
# 189  San Antonio   United States                118.00
# 53    Gothenburg          Sweden                119.17
# 68         Daegu     South Korea                132.17
# 66         Busan     South Korea                129.00
#
#      average_rating_notNone  rank_extra  rank_notNone  rank_notNone_break
# 149                    37.0         158            38                -120
# 54                     55.0         175            61                -114
# 184                     5.0          84             4                 -80
# 199                    48.0         129            50                 -79
# 198                    46.5         124            46                 -78
# 194                    99.0         187           114                 -73
# 200                    55.5         134            63                 -71
# 201                    55.5         135            64                 -71
# 195                   104.0         189           119                 -70
# 185                    22.3          92            26                 -66
# 186                    30.3          94            30                 -64
# 187                    39.7          99            41                 -58
# 202                    78.0         147            90                 -57
# 188                    47.0         105            49                 -56
# 160                   115.0         186           130                 -56
# 115                   118.0         176           134                 -42
# 189                    65.3         110            70                 -40
# 53                     66.3         113            73                 -40
# 68                     92.3         137           106                 -31
# 66                     86.0         128            97                 -31

# %%
sns.histplot(data=rank_matching_3_break['rank_notNone'], kde=True)
# Out:
# <AxesSubplot:xlabel='rank_notNone', ylabel='Count'>

# %%
df4 = rank_matching_3[['City', 'average_rating_extra', 'average_rating_notNone', 
                       'rank_extra', 'rank_notNone']].sort_values(by='rank_notNone', 
                                                                  ascending = True).reset_index().drop(columns=['index'])
df4.plot.line(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Стабильность и потенциал развития городов по категориям

# %% [markdown]
# Смотрим зависимость итогового рейтинга города от вариабельности отдельных рейтингов по категориям (стандартного отклонения отдельных рейтингов от среднего). Возможно, это не совсем верно, т.к. итоговый рейтинг получается не средним арифметическим, а с учетом весовых коэф-тов категорий. Но колеблемость/амплитудность мест будет отражаться верно.
# По итогам будем делить на четыре блока:
# 1. успешные и стабильные (места в первой половине выборки, отклонения между рейтингами категорий небольшое)
# 2. успешные и нестабильные (места в первой половине выборки, отклонения между рейтингами категорий большое)
# 3. отстающие и не подающие надежд (места во второй половине, отклонения между рейтингами категорий небольшое)
# 4. отстающие и потенциально способные прорваться (места во второй половине, отклонения между рейтингами категорий большое)

# %%
full_rank_2019['stdev_category_rating'] = np.std(full_rank_2019[['Economy', 'Human capital', 'Social cohesion',
                                                       'Environment', 'Governance', 'Urban planning', 
                                                       'International projection', 'Technology', 
                                                        'Mobility and Transportation']], axis=1).round(2)
full_rank_2019
# Out:
#     City_origin  Country_origin           City         Country  Ranking 2019  \
# 0        London  United Kingdom         London  United Kingdom             1
# 1      New York             USA  New York City   United States             2
# 2         Paris          France          Paris          France             3
# 3         Tokyo           Japan          Tokyo           Japan             4
# 4     Reykjavík         Iceland      Reykjavik         Iceland             5
# ..          ...             ...            ...             ...           ...
# 111     Bangkok        Thailand        Bangkok        Thailand           112
# 112      Panama          Panama    Panama City          Panama           113
# 113    San José      Costa Rica       San Jose      Costa Rica           114
# 114        Kiev         Ukraine           Kiev         Ukraine           115
# 115       Sofia        Bulgaria          Sofia        Bulgaria           116
#
#      Economy  Human capital  Social cohesion  Environment  Governance  \
# 0         14              1               64           35           2
# 1          1              3              151           69          30
# 2         13              6               74           48          44
# 3          3              9               51            6          26
# 4         86             22               14            1          25
# ..       ...            ...              ...          ...         ...
# 111      125            129              116          121         152
# 112       84            145              103           40         149
# 113      123            155              112           14          77
# 114      133            104              160          123          93
# 115      162             77               66           88          59
#
#      Urban planning  International projection  Technology  \
# 0                 2                         1           6
# 1                 1                         6           8
# 2                12                         2          20
# 3                23                        30          22
# 4               125                        16          58
# ..              ...                       ...         ...
# 111              27                        15         109
# 112              50                        80         151
# 113             132                       101         132
# 114               4                       117         152
# 115             153                       104         118
#
#      Mobility and Transportation  stdev_category_rating
# 0                              3                  20.42
# 1                              1                  47.70
# 2                              2                  23.68
# 3                             56                  17.57
# 4                             57                  38.09
# ..                           ...                    ...
# 111                          117                  44.44
# 112                          140                  41.09
# 113                          144                  40.43
# 114                          124                  43.11
# 115                          104                  34.01
#
# [116 rows x 15 columns]

# %%
x = full_rank_2019['Ranking 2019']
y = full_rank_2019['stdev_category_rating']
labels = full_rank_2019['City']

fig, ax = plt.subplots()

ax.scatter(x, y)

# Разделить на 4 части: Успешные + Неуспешные + Стабильные + Нестабильные. На 4 отдельных графика
ax.set_xlabel('Ranking 2019')
ax.set_ylabel('Variances of Ranking in Categories 2019')
ax.grid()

# Добавим подписи возле каждого города. Пока их много, мешается, но при меньшем количестве значений или при большем
# размере графика зато будет показательно, кто именно попал в какую категорию.
for i, txt in enumerate(labels):
    ax.annotate(txt, (x[i], y[i]), fontsize = 8) 

ax.set_title('Успешность и стабильность городов в рейтинге')
fig.set_figwidth(15)    #  ширина и высота
fig.set_figheight(8)    
plt.show()

# %%
# Второй вариант: делаем 4 отдельных графика. 
# Попробуем нарисовать все 4 графика на одной картинке

x_half = full_rank_2019['Ranking 2019'].count()/2
x_max = full_rank_2019['Ranking 2019'].count()
y_half = full_rank_2019['stdev_category_rating'].max()/2
y_max = full_rank_2019['stdev_category_rating'].max()

# labels_1 = full_rank_2019['City'].loc[:x_half]
# labels_2 = full_rank_2019['City'].loc[x_half:x_max]
labels = full_rank_2019['City']

x = full_rank_2019['Ranking 2019']
y = full_rank_2019['stdev_category_rating']

fig, axs = plt.subplots(nrows=2, ncols=2)

axs[1, 0].scatter(x, y, color = 'm')
axs[1, 0].set_xlim(0, x_half)
axs[1, 0].set_ylim(0, y_half)
axs[1, 0].set_xlabel('Ranking 2019')
axs[1, 0].set_ylabel('Variances of Rankings')
axs[1, 0].set_title('Успешные и стабильные')
                        
axs[0, 0].scatter(x, y, color = 'c')
axs[0, 0].set_xlim(0, x_half)
axs[0, 0].set_ylim(y_half, y_max)
axs[0, 0].set_ylabel('Variances of Rankings')
axs[0, 0].set_title('Успешные и нестабильные')
                        
axs[0, 1].scatter(x, y, color = 'y')
axs[0, 1].set_xlim(x_half, x_max)
axs[0, 1].set_ylim(y_half, y_max)
axs[0, 1].set_title('Неуспешные с потенциалом')
                        
axs[1, 1].scatter(x, y)
axs[1, 1].set_xlim(x_half, x_max)
axs[1, 1].set_ylim(0, y_half)
axs[1, 1].set_xlabel('Ranking 2019')
axs[1, 1].set_title('Неуспешные во всем')

# axs.grid()

# Потом добавить аннотации
# for i, txt1 in enumerate(labels_1):
#     axs[0, 0].annotate(txt1, (x[i], y[i]), fontsize = 8) 
#     axs[1, 0].annotate(txt1, (x[i], y[i]), fontsize = 8) 

for i, txt in enumerate(labels):
    axs[0, 0].annotate(txt, (x[i], y[i]), fontsize = 8) 
    axs[1, 0].annotate(txt, (x[i], y[i]), fontsize = 8) 
    axs[0, 1].annotate(txt, (x[i], y[i]), fontsize = 8) 
    axs[1, 1].annotate(txt, (x[i], y[i]), fontsize = 8)

fig.suptitle('Успешность и стабильность городов в рейтинге')
fig.set_figwidth(15)    #  ширина и высота
fig.set_figheight(8) 

# fig.tight_layout()
plt.show()

# %% [markdown]
# ### Российские города в рейтинге

# %%
r1_Russia = r1[r1.Country == 'Russia'].filter(items = ['City', 'Country', 'Ranking 2014', 'Ranking 2015', 'Ranking 2016', 
                           'Ranking 2017', 'Ranking 2018', 'Ranking 2019', 'average_rating'])
r1_Russia
# Out:
#               City Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# 82          Moscow  Russia            90           108            89
# 102  St Petersburg  Russia           115           133           103
#
#      Ranking 2017  Ranking 2018  Ranking 2019  average_rating
# 82             70            86            87           88.33
# 102           123           121           124          119.83

# %%
r2_Russia = r2[r2.Country == 'Russia'].filter(items = ['City', 'Country', 'CIMI 2014', 'CIMI 2015', 'CIMI 2016', 
                           'CIMI 2017', 'CIMI 2018', 'CIMI 2019','average_CIMI'])
r2_Russia
# Out:
#               City Country  CIMI 2014  CIMI 2015  CIMI 2016  CIMI 2017  \
# 82          Moscow  Russia      57.69      58.12      61.83      55.50
# 102  St Petersburg  Russia      49.35      53.59      57.46      42.37
#
#      CIMI 2018  CIMI 2019  average_CIMI
# 82       55.91      55.74         57.46
# 102      44.12      44.78         48.61

# %%
# Это датафрейм, в котором заменены пропущенные значения рейтинга на последнее место +1.
r1_outer_Russia = r1_outer[r1_outer.Country == 'Russia'].filter(items = ['City', 'Country', 'Ranking 2014', 'Ranking 2015', 'Ranking 2016', 
                           'Ranking 2017', 'Ranking 2018', 'Ranking 2019', 'average_rating_extra'])
r1_outer_Russia
# Out:
#               City Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# 89          Moscow  Russia          90.0         108.0          89.0
# 114  St Petersburg  Russia         115.0         133.0         103.0
# 172    Novosibirsk  Russia         149.0         154.0         152.0
#
#      Ranking 2017  Ranking 2018  Ranking 2019  average_rating_extra
# 89           70.0          86.0          87.0                 88.33
# 114         123.0         121.0         124.0                119.83
# 172         142.0         156.0         159.0                152.00

# %%
# Это полная таблица рейтингов за все годы, с NaN
rаnk_2014_2019_outer_Russia = rank_2014_2019_outer[rank_2014_2019_outer.Country == 'Russia'].filter(items = ['City', 'Country', 
                            'Ranking 2014', 'Ranking 2015', 'Ranking 2016', 
                            'Ranking 2017', 'Ranking 2018', 'Ranking 2019'])
rаnk_2014_2019_outer_Russia
# Out:
#               City Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# 89          Moscow  Russia          90.0         108.0          89.0
# 114  St Petersburg  Russia         115.0         133.0         103.0
# 172    Novosibirsk  Russia           NaN         154.0         152.0
#
#      Ranking 2017  Ranking 2018  Ranking 2019
# 89           70.0          86.0          87.0
# 114         123.0         121.0         124.0
# 172         142.0         156.0         159.0

# %%
rank_matching_3[rank_matching_3.Country == 'Russia'].filter(items = ['City', 'Country', 'average_rating_extra',  
                       'average_rating_notNone', 'rank_extra', 'rank_notNone'])
# Out:
#               City Country  average_rating_extra  average_rating_notNone  \
# 89          Moscow  Russia                 88.33                    88.3
# 114  St Petersburg  Russia                119.83                   119.8
# 172    Novosibirsk  Russia                152.00                   152.6
#
#      rank_extra  rank_notNone
# 89           85           101
# 114         114           140
# 172         165           179

# %%
# Объединим средние широкие рейтинги с рейтингом 2019 г. 
# Но это узкий список, надо объединить с исходным рейтингом 2019.
rank_matching_2019 = rank_matching_3.merge(rank_2019, how = 'inner', on = ['City', 
                    'Country']).loc[:,['City', 'Country', 'rank_extra', 
                     'rank_notNone', 'Ranking 2019']].sort_values(by='Ranking 2019', 
                    ascending = True).reset_index().drop(columns=['index'])
rank_matching_2019.plot.line(figsize=(12,5))
plt.title('Рейтинг 2019 г. в сравнении с рангами по "широким" спискам №1 и №2')
# rank_matching_2019
# Out:
# Text(0.5, 1.0, 'Рейтинг 2019 г. в сравнении с рангами по "широким" спискам №1 и №2')

# %%
rank_matching_2019.corr()
# Рейтинг 2019 показывает больше корреляцию с рейтингом широкого списка №2. Возможно, из-за Рейкьявика и других прорывов
# Out:
#               rank_extra  rank_notNone  Ranking 2019
# rank_extra      1.000000      0.935003      0.902913
# rank_notNone    0.935003      1.000000      0.981978
# Ranking 2019    0.902913      0.981978      1.000000

# %%
# Объединим средние широкие рейтинги с рейтингом 2016 г. (или любого другого года)
rank_matching_2016 = rank_matching_3.merge(rank_2016, how = 'inner', on = ['City', 
                    'Country']).loc[:,['City', 'Country', 'rank_extra', 
                     'rank_notNone', 'Ranking 2016']].sort_values(by='Ranking 2016', 
                    ascending = True).reset_index().drop(columns=['index'])
rank_matching_2016.plot.line(figsize=(12,5))
plt.title('Рейтинг 2016 г. в сравнении с рангами по "широким" спискам №1 и №2')
# rank_matching_2019
# Out:
# Text(0.5, 1.0, 'Рейтинг 2016 г. в сравнении с рангами по "широким" спискам №1 и №2')

# %%
rank_matching_2016.corr()
# Рейтинг 2016 показывает почти одинаковую хорошую корреляцию с рейтингами широкого списка №2 и №1.
# Out:
#               rank_extra  rank_notNone  Ranking 2016
# rank_extra      1.000000      0.976193      0.972414
# rank_notNone    0.976193      1.000000      0.978729
# Ranking 2016    0.972414      0.978729      1.000000

# %% [markdown]
# Сравнение рейтингов по сокращенному и двум расширенным рейтингам на примере городов России показывает:
# 1. "Узкое" объединение рейтингов и индексов за все годы с последующим усреднением не позволяет определить реальное среднее место города за период. Потому что из рейтингов выпадает большое количество городов, не попавших хотя бы в один из рейтингов, но реально изменяющих общий рейтинг в некоторые годы. 87 городов из общего числа 206 когда-либо оцениваемых городов не попадает в "узкий" объединенный список (42%).
# 2. Если использовать метод усреднения NaN = 0 в "широком" объединении рейтингов, то средний рейтинг города чаще становится хуже за счет допуска нерегулярных или недавно подключившихся участников. Может быть несправедливым. Город, стабильно участвующий в рейтинге, проигрывает новичку из одного-двух последних списков. Но гораздо интереснее кажется обратное: если город стал участовать недавно и занимает хорошие позиции, то его незаслуженно оттеснять штрафным усреднением на задние места. Как показало сравнение двух видов рейтингов из широкого списка, таких прорывных городов достаточно
# 3. Метод усреднения по принципу NaN = последнее место + 1 казался поначалу более объективным. Допускаются все участники: если не участвовал ранее, то становится в конце списка. Было предположение, что несколько пропусков по годам не сильно ухудшит позицию по такому усреднению. Но оказалось, что в рейтинг прорвались города, которые смогли стать лидерами или существенно потеснить других постоянных участников.
# Таким образом, выведение рейтинга по среднему без штрафных очков оказывается менее стабильным, но более приближенным к реальности.

# %% [markdown]
# ### Распределение умных городов по регионам и странам

# %% [markdown]
# Добавляем регионы: сколько стран в каждом регионе участвовало, среди всех годов

# %%
regions = pd.read_excel('CountriesByRegions.xlsx')
regions_in_rank = rank_2014_2019_outer.merge(regions, on = ['Country']).loc[:,['City', 
                                'Country', 'Region', 'Ranking 2014', 'Ranking 2015', 
                                'Ranking 2016', 'Ranking 2017', 'Ranking 2018', 'Ranking 2019']]
regions_in_rank
# 6 стран потерялись. Видимо, написание стран в рейтинге отличается от написания стран в перечне стран по регионам. Не существенно
# regions_in_rank.groupby(['Region', 'Country']).head(10)
# regions_in_rank['Region'].value_counts()# .value_counts()
# df.groupby(["id", "group"])["term"].value_counts().unstack(fill_value=0)
# Out:
#             City         Country           Region  Ranking 2014  Ranking 2015  \
# 0         London  United Kingdom           Europe           1.0           2.0
# 1      Liverpool  United Kingdom           Europe          20.0          48.0
# 2     Birmingham  United Kingdom           Europe          23.0          47.0
# 3        Glasgow  United Kingdom           Europe          26.0          46.0
# 4     Manchester  United Kingdom           Europe          31.0          43.0
# ..           ...             ...              ...           ...           ...
# 195      Karachi        Pakistan             Asia           NaN         181.0
# 196       Lahore        Pakistan             Asia           NaN           NaN
# 197    Reykjavik         Iceland           Europe           NaN           NaN
# 198  Panama City          Panama  Central America           NaN           NaN
# 199     Asuncion        Paraguay    South America           NaN           NaN
#
#      Ranking 2016  Ranking 2017  Ranking 2018  Ranking 2019
# 0             2.0           2.0           1.0           1.0
# 1            55.0          82.0          94.0          94.0
# 2            62.0          58.0          63.0          73.0
# 3            39.0          68.0          64.0          66.0
# 4            57.0          59.0          78.0          71.0
# ..            ...           ...           ...           ...
# 195         180.0         165.0         174.0         173.0
# 196           NaN           NaN         173.0         172.0
# 197           NaN           5.0           5.0           5.0
# 198           NaN          94.0         114.0         113.0
# 199           NaN           NaN         141.0         131.0
#
# [200 rows x 9 columns]

# %%
regions_in_rank.groupby(['Region']).count()
# regions_in_rank.groupby(['Region', 'Country']).count()
# stats.groupby(['group', 'campaign']).count().head()
# Out:
#                  City  Country  Ranking 2014  Ranking 2015  Ranking 2016  \
# Region
# Africa             12       12             6            11            11
# Asia               51       51            36            47            47
# Australia           2        2             2             2             2
# Central America     7        7             4             6             6
# Europe             80       80            58            70            70
# North America      22       22            15            17            16
# Oceania             2        2             1             1             1
# South America      24       24            21            23            23
#
#                  Ranking 2017  Ranking 2018  Ranking 2019
# Region
# Africa                      9             9             9
# Asia                       34            36            36
# Australia                   2             2             2
# Central America             5             5             5
# Europe                     75            76            76
# North America              18            21            21
# Oceania                     2             2             2
# South America              20            21            21

# %%
# Чтобы смотреть, какие страны входят в регион
regions_in_rank[regions_in_rank.Region == 'South America'].groupby(['Region', 'Country', 'City']).count()
# Out:
#                                         Ranking 2014  Ranking 2015  \
# Region        Country   City
# South America Argentina Buenos Aires               1             1
#                         Cordoba                    1             1
#                         Rosario                    1             1
#               Bolivia   La Paz                     1             1
#                         Santa Cruz                 0             1
#               Brasil    Belo Horizonte             1             1
#                         Brasilia                   1             1
#                         Curitiba                   1             1
#                         Fortaleza                  1             1
#                         Porto Alegre               1             1
#                         Recife                     1             1
#                         Rio de Janeiro             1             1
#                         Salvador                   1             1
#                         São Paulo                  1             1
#               Chile     Santiago                   1             1
#               Colombia  Bogota                     1             1
#                         Cali                       1             1
#                         Medellín                   1             1
#               Ecuador   Guayaquil                  0             1
#                         Quito                      1             1
#               Paraguay  Asuncion                   0             0
#               Peru      Lima                       1             1
#               Uruguay   Montevideo                 1             1
#               Venezuela Caracas                    1             1
#
#                                         Ranking 2016  Ranking 2017  \
# Region        Country   City
# South America Argentina Buenos Aires               1             1
#                         Cordoba                    1             1
#                         Rosario                    1             1
#               Bolivia   La Paz                     1             1
#                         Santa Cruz                 1             1
#               Brasil    Belo Horizonte             1             1
#                         Brasilia                   1             1
#                         Curitiba                   1             1
#                         Fortaleza                  1             0
#                         Porto Alegre               1             0
#                         Recife                     1             0
#                         Rio de Janeiro             1             1
#                         Salvador                   1             1
#                         São Paulo                  1             1
#               Chile     Santiago                   1             1
#               Colombia  Bogota                     1             1
#                         Cali                       1             1
#                         Medellín                   1             1
#               Ecuador   Guayaquil                  1             1
#                         Quito                      1             1
#               Paraguay  Asuncion                   0             0
#               Peru      Lima                       1             1
#               Uruguay   Montevideo                 1             1
#               Venezuela Caracas                    1             1
#
#                                         Ranking 2018  Ranking 2019
# Region        Country   City
# South America Argentina Buenos Aires               1             1
#                         Cordoba                    1             1
#                         Rosario                    1             1
#               Bolivia   La Paz                     1             1
#                         Santa Cruz                 1             1
#               Brasil    Belo Horizonte             1             1
#                         Brasilia                   1             1
#                         Curitiba                   1             1
#                         Fortaleza                  0             0
#                         Porto Alegre               0             0
#                         Recife                     0             0
#                         Rio de Janeiro             1             1
#                         Salvador                   1             1
#                         São Paulo                  1             1
#               Chile     Santiago                   1             1
#               Colombia  Bogota                     1             1
#                         Cali                       1             1
#                         Medellín                   1             1
#               Ecuador   Guayaquil                  1             1
#                         Quito                      1             1
#               Paraguay  Asuncion                   1             1
#               Peru      Lima                       1             1
#               Uruguay   Montevideo                 1             1
#               Venezuela Caracas                    1             1

# %%
# Диаграмма-боксплот среднего количества мест за все годы. Показывает только размах количества городов в разных отчетах.
# Не показательно. 
regions_in_rank.boxplot(grid=False, rot=90)
# Out:
# <AxesSubplot:>

# %%
# Показывает участие стран по количеству городов и оценкам в отчете с рейтингом 2019 г. 
# Минус диаграммы - нет цвета, плохо поддается расстановке меток, изменению вида. По сути - хорошо.
regions_in_rank.boxplot(column=['Ranking 2019'], by=['Region'], rot=90, grid=False, figsize=(9, 5))
plt.title("Города в рейтинге 2019 г. по регионам", ha = 'center')
# Out:
# Text(0.5, 1.0, 'Города в рейтинге 2019 г. по регионам')

# %%
regions_in_rank.groupby(['Region']).mean().round(1)
# Out:
#                  Ranking 2014  Ranking 2015  Ranking 2016  Ranking 2017  \
# Region
# Africa                  130.0         159.3         161.8         153.1
# Asia                     91.9         118.3         118.7         103.1
# Australia                21.5          13.5          15.0          13.5
# Central America         111.5         130.3         124.8         119.6
# Europe                   50.3          64.5          62.1          65.1
# North America            38.7          22.2          20.2          36.4
# Oceania                  38.0          29.0          44.0          23.0
# South America           116.4         130.7         128.1         130.0
#
#                  Ranking 2018  Ranking 2019
# Region
# Africa                  163.7         159.8
# Asia                    115.3         114.1
# Australia                19.5          27.0
# Central America         131.6         130.4
# Europe                   66.5          66.0
# North America            40.7          42.4
# Oceania                  30.5          29.0
# South America           131.1         135.0

# %%
regions_in_rank_table = regions_in_rank.loc[:,['Region', 'Ranking 2019']].groupby(
    ['Region']).agg({'Ranking 2019' : ['count', 'mean']}).round(1)
regions_in_rank_table
# Out:
#                 Ranking 2019
#                        count   mean
# Region
# Africa                     9  159.8
# Asia                      36  114.1
# Australia                  2   27.0
# Central America            5  130.4
# Europe                    76   66.0
# North America             21   42.4
# Oceania                    2   29.0
# South America             21  135.0

# %%
a = regions_in_rank.groupby(['Region']).mean().round(1).sort_values(by='Ranking 2019', ascending=True)
a.plot.bar(figsize=(13, 4))

plt.title("Среднее место в рейтинге городов по регионам")
# plt.xlabel("Family Member")
plt.ylabel("Место в рейтинге (меньше - лучше)")
plt.legend(loc='upper left', ncol=len(a.columns))
plt.yticks([0, 50, 100, 150])
plt.grid(axis='y')

# %%
# Другой вариант, график через детализацию в mathplotlib. Более громоздкий.
a1 = regions_in_rank.groupby(['Region']).mean().round(1).sort_values(by='Ranking 2019', ascending=True).reset_index()
x = a1['Region']
# y = a1[['Ranking 2014', 'Ranking 2015', 'Ranking 2016', 'Ranking 2017', 'Ranking 2018', 'Ranking 2019']] Такой
# массив не берет сразу через ax.bar. Нужно по отдельности каждый ряд и потом разносить по ширине через width +|-
y1 = a1['Ranking 2014']
y2 = a1['Ranking 2015']
y3 = a1['Ranking 2016']
y4 = a1['Ranking 2017']
y5 = a1['Ranking 2018']
y6 = a1['Ranking 2019']
x1 = np.arange(len(x))
width = 0.1

fig, ax = plt.subplots(figsize = (12,4))
# fig.set_figwidth(10)
# fig.set_figheight(3)
ax.bar(x1-3*width, y1, width, label = 'Ranking 2014')
ax.bar(x1-2*width, y2, width, label = 'Ranking 2015')
ax.bar(x1-width, y3, width, label = 'Ranking 2016')
ax.bar(x1, y4, width, label = 'Ranking 2017')
ax.bar(x1+width, y5, width, label = 'Ranking 2018')
ax.bar(x1+2*width, y6, width, label = 'Ranking 2019')

ax.legend()

xticks = x1
ax.set_xticks(xticks)
ax.set_xticklabels(x, rotation=90)

ax.set_title("Среднее место в рейтинге городов по регионам")
ax.set_ylabel("Место в рейтинге (меньше - лучше)")

plt.show()

# %%
regions_in_CIMI = rank_2014_2019_outer.merge(regions, on = ['Country']).loc[:,['City', 
                                'Country', 'Region', 'CIMI 2014', 'CIMI 2015', 
                                'CIMI 2016', 'CIMI 2017', 'CIMI 2018', 'CIMI 2019']]
regions_in_CIMI.groupby(['Region']).mean().round(1)
# Out:
#                  CIMI 2014  CIMI 2015  CIMI 2016  CIMI 2017  CIMI 2018  \
# Region
# Africa                43.1       44.3       41.5       28.7       25.2
# Asia                  56.1       56.0       53.5       46.4       44.2
# Australia             79.1       85.4       81.6       74.2       75.2
# Central America       50.0       52.7       52.2       41.7       41.0
# Europe                70.0       70.7       68.2       57.7       61.5
# North America         73.8       83.8       81.1       66.4       68.3
# Oceania               73.2       79.6       71.2       69.0       71.0
# South America         48.1       53.2       51.1       38.1       39.4
#
#                  CIMI 2019
# Region
# Africa                29.9
# Asia                  45.7
# Australia             70.3
# Central America       42.5
# Europe                60.8
# North America         66.9
# Oceania               69.5
# South America         39.5

# %%
regions_in_CIMI_table = regions_in_CIMI.loc[:,['Region', 'CIMI 2019']].groupby(
    ['Region']).agg({'CIMI 2019' : ['mean']}).round(1)
regions_table = regions_in_rank_table.merge(regions_in_CIMI_table, on = ['Region']).sort_values(
    by=('Ranking 2019', 'mean'))
regions_table
# Out:
#                 Ranking 2019        CIMI 2019
#                        count   mean      mean
# Region
# Australia                  2   27.0      70.3
# Oceania                    2   29.0      69.5
# North America             21   42.4      66.9
# Europe                    76   66.0      60.8
# Asia                      36  114.1      45.7
# Central America            5  130.4      42.5
# South America             21  135.0      39.5
# Africa                     9  159.8      29.9

# %%
b = regions_in_CIMI.groupby(['Region']).mean().round(1).sort_values(by='CIMI 2019', ascending=False)
b.plot.bar(figsize=(14, 4))

plt.title("Средний индекс CIMI городов по регионам")
# plt.xlabel("Family Member")
plt.ylabel("Индекс (больше - лучше)")
plt.legend(loc='upper center', ncol=len(b.columns))
plt.yticks([0, 20, 40, 60, 80, 100])
plt.grid(axis='y')

# Видно, что индексы Австралии, Океании, Северной Америки и Европы довольно близки, хотя средний рейтинг у Европы 
# гораздо дальше отстоит от Австралии/Океании

# %% [markdown]
# Посмотрим состав в рейтинге по странам

# %%
countries_in_rank = regions_in_rank.groupby(['Country']).count().sort_values(by = 'Ranking 2019', ascending = False)
countries_in_rank = countries_in_rank[countries_in_rank['Ranking 2019'] > 2]
countries_in_rank
# Out:
#                 City  Region  Ranking 2014  Ranking 2015  Ranking 2016  \
# Country
# United States     16      16            11            12            12
# Spain             12      12             7             7             7
# Germany            8       8             7             7             7
# United Kingdom     8       8             7             7             7
# China             11      11            11            11            11
# Brasil             9       9             9             9             9
# France             5       5             5             5             5
# Italy              5       5             5             5             5
# Canada             6       6             4             5             4
# India              6       6             4             4             4
# Switzerland        4       4             3             3             3
# Japan              3       3             2             3             3
# Russia             3       3             2             3             3
# Colombia           3       3             3             3             3
# Argentina          3       3             3             3             3
# Netherlands        3       3             2             3             3
#
#                 Ranking 2017  Ranking 2018  Ranking 2019
# Country
# United States             14            16            16
# Spain                     12            10            10
# Germany                    7             8             8
# United Kingdom             7             8             8
# China                      6             6             6
# Brasil                     6             6             6
# France                     5             5             5
# Italy                      5             5             5
# Canada                     4             5             5
# India                      3             4             4
# Switzerland                4             4             4
# Japan                      3             3             3
# Russia                     3             3             3
# Colombia                   3             3             3
# Argentina                  3             3             3
# Netherlands                3             3             3

# %% [markdown]
# ### Рейтинг городов по размеру населения

# %%
# Смотрим по всем городам в рейтингах за 6 лет
populations = pd.read_excel('CitiesPopulations.xlsx')
populations_in_rank = rank_2014_2019_outer.merge(populations, on = ['City', 'Country']).loc[:,['City', 
                                                                        'Country', 'Population2021']]
populations_in_rank['Population2021'] = populations_in_rank['Population2021'] / 1000
populations_in_rank
# Out:
#               City          Country  Population2021
# 0           London   United Kingdom        9425.622
# 1    New York City    United States        8230.290
# 2            Seoul      South Korea        9967.677
# 3            Paris           France       11078.546
# 4        Amsterdam      Netherlands        1157.519
# ..             ...              ...             ...
# 172        Seattle    United States         776.555
# 173    Quebec City           Canada         831.776
# 174       Asuncion         Paraguay        3394.309
# 175         Skopje  North Macedonia         600.708
# 176         Lahore         Pakistan       13095.166
#
# [177 rows x 3 columns]

# %%
populations_in_rank['Population2021'].min()
# Out:
# 504.491

# %%
# populations_in_rank.plot.hist(bins=20) Это простой способ построения графика, к нему плохо добавлять опции графика
y = populations_in_rank['Population2021']

fig, ax = plt.subplots()
fig.set_figwidth(12)
ax.hist(y, 30, color='tab:orange')
# ax.set_xlim([100, 5000])
ax.set_xlabel('Population, in thouthands')
plt.title('Распределение городов по численности населения в рейтингах с 2014 по 2019 гг.')
plt.show()

# %%
# Функция определяет, к какой категории по размеру населения отнести город.
def city_size(row):
    if (row['Population2021'] > 10000):
        return 'Mega'
    elif (row['Population2021'] > 5000):
        return 'Large'
    elif (row['Population2021'] > 1000):
        return 'Medium'
    elif (row['Population2021'] > 600):
        return 'Small'
    else: 
        return 'Smallest'
#  Функция для показа минимального размера населения в категории, в тысячах человек, чтобы расставлять по возрастанию   
def city_size_in_thou(row):
    if (row['Population2021'] > 10000):
        return '10000'
    elif (row['Population2021'] > 5000):
        return '5000'
    elif (row['Population2021'] > 1000):
        return '1000'
    elif (row['Population2021'] > 600):
        return '600'
    else: 
        return '500'

# %%
# Оставляем город, страну и размер города
city_size_in_rank = pd.concat([populations_in_rank[['City', 'Country']], pd.Series(
    populations_in_rank.apply(city_size, axis=1), name = 'City size'), pd.Series(
    populations_in_rank.apply(city_size_in_thou, axis=1), name = 'More than in thousands')], axis=1)
city_size_in_rank['More than in thousands'] = pd.to_numeric(city_size_in_rank['More than in thousands'])
# city_size_in_rank = city_size_in_rank.sort_values(by='More than in thousands', ascending=False)
city_size_in_rank
# Out:
#               City          Country City size  More than in thousands
# 0           London   United Kingdom     Large                    5000
# 1    New York City    United States     Large                    5000
# 2            Seoul      South Korea     Large                    5000
# 3            Paris           France      Mega                   10000
# 4        Amsterdam      Netherlands    Medium                    1000
# ..             ...              ...       ...                     ...
# 172        Seattle    United States     Small                     600
# 173    Quebec City           Canada     Small                     600
# 174       Asuncion         Paraguay    Medium                    1000
# 175         Skopje  North Macedonia     Small                     600
# 176         Lahore         Pakistan      Mega                   10000
#
# [177 rows x 4 columns]

# %%
# Делаем таблицу для графика
city_size_grouped = city_size_in_rank.groupby(['More than in thousands']).count().reset_index()
city_size_grouped
# Out:
#    More than in thousands  City  Country  City size
# 0                     500     7        7          7
# 1                     600    25       25         25
# 2                    1000    94       94         94
# 3                    5000    23       23         23
# 4                   10000    28       28         28

# %%
city_size_grouped.plot.bar(
    x = 'More than in thousands',
    y = 'City',
    figsize=(10, 3), legend = False)
plt.title("Количество городов в рейтингах 2014-2019 по размеру населения")
plt.ylabel("Количество городов")
plt.xlabel("Население, больше чем, в тыс. человек")
plt.xticks(rotation = 0)
# plt.grid(axis='y')
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '500'),
#   Text(1, 0, '600'),
#   Text(2, 0, '1000'),
#   Text(3, 0, '5000'),
#   Text(4, 0, '10000')])

# %%
top_5_smallest_cities = city_size_in_rank[city_size_in_rank['City size'] == 'Smallest'].merge(rank_2014_2019_outer, on = [
    'City', 'Country']).loc[:,['City', 'Country', 'City size', 'Ranking 2019', 'Ranking 2018', 'Ranking 2017']].sort_values(
    by = 'Ranking 2019', ascending = True).head(5)
top_5_smallest_cities
# Out:
#         City         Country City size  Ranking 2019  Ranking 2018  \
# 0      Basel     Switzerland  Smallest          21.0          29.0
# 6  Edinburgh  United Kingdom  Smallest          47.0          46.0
# 3  Baltimore   United States  Smallest          61.0          71.0
# 4    Vilnius       Lithuania  Smallest          65.0          74.0
# 2     Malaga           Spain  Smallest          82.0          80.0
#
#    Ranking 2017
# 0          34.0
# 6           NaN
# 3          77.0
# 4          61.0
# 2          89.0

# %% [markdown]
# Выведем топ-5 городов в каждой категории по размеру города, с местом в рейтинге и индексами 2019, с историей за прошлые годы
# Мы не будем сравнивать показатели топ-5 из каждой категории, т.к. уже установили, что корреляции между населением города и его высоким рейтингом нет. Просто покажем лучших представителей каждой категории

# %%
top_5_small_cities = city_size_in_rank[city_size_in_rank['City size'] == 'Small'].merge(rank_2014_2019_outer, on = [
    'City', 'Country']).loc[:,['City', 'Country', 'City size', 'Ranking 2019', 'Ranking 2018', 'Ranking 2017']].sort_values(
    by = 'Ranking 2019', ascending = True).head(5)
top_5_small_cities
# Out:
#             City        Country City size  Ranking 2019  Ranking 2018  \
# 2     Washington  United States     Small          15.0          23.0
# 4  San Francisco  United States     Small          20.0          21.0
# 1         Boston  United States     Small          28.0          25.0
# 5      Frankfurt        Germany     Small          32.0          33.0
# 0         Geneva    Switzerland     Small          34.0          32.0
#
#    Ranking 2017
# 2          20.0
# 4          27.0
# 1          21.0
# 5          42.0
# 0          32.0

# %%
top_5_medium_cities = city_size_in_rank[city_size_in_rank['City size'] == 'Medium'].merge(rank_2014_2019_outer, on = [
    'City', 'Country']).loc[:,['City', 'Country', 'City size', 'Ranking 2019', 'Ranking 2018', 'Ranking 2017']].sort_values(
    by = 'Ranking 2019', ascending = True).head(5)
top_5_medium_cities
# Out:
#           City      Country City size  Ranking 2019  Ranking 2018  \
# 6   Copenhagen      Denmark    Medium           6.0           8.0
# 11      Berlin      Germany    Medium           7.0           9.0
# 0    Amsterdam  Netherlands    Medium           8.0           3.0
# 3       Zurich  Switzerland    Medium          11.0          15.0
# 5         Oslo       Norway    Medium          12.0          14.0
#
#     Ranking 2017
# 6           13.0
# 11          11.0
# 0           10.0
# 3           24.0
# 5           23.0

# %%
top_5_large_cities = city_size_in_rank[city_size_in_rank['City size'] == 'Large'].merge(rank_2014_2019_outer, on = [
    'City', 'Country']).loc[:,['City', 'Country', 'City size', 'Ranking 2019', 'Ranking 2018', 'Ranking 2017']].sort_values(
    by = 'Ranking 2019', ascending = True).head(5)
top_5_large_cities
# Out:
#             City         Country City size  Ranking 2019  Ranking 2018  \
# 0         London  United Kingdom     Large           1.0           1.0
# 1  New York City   United States     Large           2.0           2.0
# 3      Singapore       Singapore     Large           9.0           7.0
# 2          Seoul     South Korea     Large          19.0          12.0
# 6         Madrid           Spain     Large          25.0          24.0
#
#    Ranking 2017
# 0           2.0
# 1           1.0
# 3           6.0
# 2           7.0
# 6          25.0

# %%
top_5_mega_cities = city_size_in_rank[city_size_in_rank['City size'] == 'Mega'].merge(rank_2014_2019_outer, on = [
    'City', 'Country']).loc[:,['City', 'Country', 'City size', 'Ranking 2019', 'Ranking 2018', 'Ranking 2017']].sort_values(
    by = 'Ranking 2019', ascending = True).head(5)
top_5_mega_cities
# Out:
#         City Country City size  Ranking 2019  Ranking 2018  Ranking 2017
# 0      Paris  France      Mega           3.0           4.0           3.0
# 1      Tokyo   Japan      Mega           4.0           6.0           4.0
# 4   Shanghai   China      Mega          58.0          59.0          57.0
# 2      Osaka   Japan      Mega          64.0          68.0          56.0
# 10   Beijing   China      Mega          84.0          83.0          78.0

# %%
top_5_concat = pd.concat([top_5_smallest_cities, top_5_small_cities, top_5_medium_cities, 
                          top_5_large_cities, top_5_mega_cities])
top_5_concat
# Out:
#              City         Country City size  Ranking 2019  Ranking 2018  \
# 0           Basel     Switzerland  Smallest          21.0          29.0
# 6       Edinburgh  United Kingdom  Smallest          47.0          46.0
# 3       Baltimore   United States  Smallest          61.0          71.0
# 4         Vilnius       Lithuania  Smallest          65.0          74.0
# 2          Malaga           Spain  Smallest          82.0          80.0
# 2      Washington   United States     Small          15.0          23.0
# 4   San Francisco   United States     Small          20.0          21.0
# 1          Boston   United States     Small          28.0          25.0
# 5       Frankfurt         Germany     Small          32.0          33.0
# 0          Geneva     Switzerland     Small          34.0          32.0
# 6      Copenhagen         Denmark    Medium           6.0           8.0
# 11         Berlin         Germany    Medium           7.0           9.0
# 0       Amsterdam     Netherlands    Medium           8.0           3.0
# 3          Zurich     Switzerland    Medium          11.0          15.0
# 5            Oslo          Norway    Medium          12.0          14.0
# 0          London  United Kingdom     Large           1.0           1.0
# 1   New York City   United States     Large           2.0           2.0
# 3       Singapore       Singapore     Large           9.0           7.0
# 2           Seoul     South Korea     Large          19.0          12.0
# 6          Madrid           Spain     Large          25.0          24.0
# 0           Paris          France      Mega           3.0           4.0
# 1           Tokyo           Japan      Mega           4.0           6.0
# 4        Shanghai           China      Mega          58.0          59.0
# 2           Osaka           Japan      Mega          64.0          68.0
# 10        Beijing           China      Mega          84.0          83.0
#
#     Ranking 2017
# 0           34.0
# 6            NaN
# 3           77.0
# 4           61.0
# 2           89.0
# 2           20.0
# 4           27.0
# 1           21.0
# 5           42.0
# 0           32.0
# 6           13.0
# 11          11.0
# 0           10.0
# 3           24.0
# 5           23.0
# 0            2.0
# 1            1.0
# 3            6.0
# 2            7.0
# 6           25.0
# 0            3.0
# 1            4.0
# 4           57.0
# 2           56.0
# 10          78.0

# %%
# Простая диаграмма топ-5 в каждой категории городов по населению.
top_5_concat.plot.bar(
    x = 'City size',
    y = 'Ranking 2019')
# Out:
# <AxesSubplot:xlabel='City size'>

# %%
x = top_5_concat['City']
y = top_5_concat['Ranking 2019']

labels = top_5_concat['City size']
newlabels = []
oldlabels = labels.to_list()
for i in range(0, len(oldlabels)):
    if (i % 5) == 0:
        newlabels.append(oldlabels[i])
newlabels        

fig, ax = plt.subplots()

color_rectangle = ['b','b','b','b','b',
                  'g','g','g','g','g',
                  'c','c','c','c','c',
                  'm','m','m','m','m',
                  'y','y','y','y','y',
                  ]
ax.bar(x, y, color = color_rectangle)
ax.set_xticklabels(newlabels, rotation='vertical')
ax.set_xticks(np.arange(0, len(oldlabels), 5))
ax.set_ylabel('Ranking 2019')
ax.set_title('Топ-5 в рейтинге умных городов по типам "крупности", по размеру населения')
fig.set_figwidth(12)    #  ширина и
fig.set_figheight(4)    #  высота "Figure"

plt.show()
# Видно, что лучшие представители - в средних и крупных городах. В небольших городах тоже достаточно неплохие лидеры. 
# В крайних случаях - маленьких и очень больших городах - лидерство - скорее исключительное свойство отдельного города.
# Out:
# <ipython-input-241-95bc9c99992f>:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(newlabels, rotation='vertical')

# %%
# Для графика рассеяния - показываем, что рейтинг не зависит от населения города
populations_in_rank_2019 = rank_2014_2019_outer.merge(populations_in_rank, on = ['City', 'Country']).loc[:,['City', 
                                                                        'Country', 'Population2021', 'Ranking 2019']]
populations_in_rank_2019
# Out:
#               City          Country  Population2021  Ranking 2019
# 0           London   United Kingdom        9425.622           1.0
# 1    New York City    United States        8230.290           2.0
# 2            Seoul      South Korea        9967.677          19.0
# 3            Paris           France       11078.546           3.0
# 4        Amsterdam      Netherlands        1157.519           8.0
# ..             ...              ...             ...           ...
# 172        Seattle    United States         776.555          53.0
# 173    Quebec City           Canada         831.776          89.0
# 174       Asuncion         Paraguay        3394.309         131.0
# 175         Skopje  North Macedonia         600.708         141.0
# 176         Lahore         Pakistan       13095.166         172.0
#
# [177 rows x 4 columns]

# %%
populations_in_rank_2019.plot.scatter(
    x = 'Population2021',
    y = 'Ranking 2019')
plt.title('Рейтинг городов 2019 г. по количеству населения')
# Out:
# Text(0.5, 1.0, 'Рейтинг городов 2019 г. по количеству населения')

# %%
populations_in_rank_2019[['Population2021', 'Ranking 2019']].corr()
# На графике и по коэф-ту видно, что корреляции между размером города и его местом в рейтинге нет - на всей выборке
# Проверим на топ-50.
# Out:
#                 Population2021  Ranking 2019
# Population2021        1.000000      0.172986
# Ranking 2019          0.172986      1.000000

# %%
populations_in_rank_2019.plot.scatter(
    x = 'Population2021',
    y = 'Ranking 2019')
plt.axis((0,40000,0,50))
plt.show()
# У топ-50 тоже не видно зависимости населения от места в рейтинге. 
# Но когда выводим топ-5 для каждой категории, то видно, что средние и крупные города побеждают.

# %% [markdown]
# ### Топ-5 городов по категориям рейтинга в 2019 г.

# %% [markdown]
# Кроме лидеров по итоговому рейтингу интересует, какие города попали в топ-5 по каждой категории.

# %%
full_rank_2019
# Out:
#     City_origin  Country_origin           City         Country  Ranking 2019  \
# 0        London  United Kingdom         London  United Kingdom             1
# 1      New York             USA  New York City   United States             2
# 2         Paris          France          Paris          France             3
# 3         Tokyo           Japan          Tokyo           Japan             4
# 4     Reykjavík         Iceland      Reykjavik         Iceland             5
# ..          ...             ...            ...             ...           ...
# 111     Bangkok        Thailand        Bangkok        Thailand           112
# 112      Panama          Panama    Panama City          Panama           113
# 113    San José      Costa Rica       San Jose      Costa Rica           114
# 114        Kiev         Ukraine           Kiev         Ukraine           115
# 115       Sofia        Bulgaria          Sofia        Bulgaria           116
#
#      Economy  Human capital  Social cohesion  Environment  Governance  \
# 0         14              1               64           35           2
# 1          1              3              151           69          30
# 2         13              6               74           48          44
# 3          3              9               51            6          26
# 4         86             22               14            1          25
# ..       ...            ...              ...          ...         ...
# 111      125            129              116          121         152
# 112       84            145              103           40         149
# 113      123            155              112           14          77
# 114      133            104              160          123          93
# 115      162             77               66           88          59
#
#      Urban planning  International projection  Technology  \
# 0                 2                         1           6
# 1                 1                         6           8
# 2                12                         2          20
# 3                23                        30          22
# 4               125                        16          58
# ..              ...                       ...         ...
# 111              27                        15         109
# 112              50                        80         151
# 113             132                       101         132
# 114               4                       117         152
# 115             153                       104         118
#
#      Mobility and Transportation  stdev_category_rating
# 0                              3                  20.42
# 1                              1                  47.70
# 2                              2                  23.68
# 3                             56                  17.57
# 4                             57                  38.09
# ..                           ...                    ...
# 111                          117                  44.44
# 112                          140                  41.09
# 113                          144                  40.43
# 114                          124                  43.11
# 115                          104                  34.01
#
# [116 rows x 15 columns]

# %%
# Выбираем столбец с топ-5 по категории Экономика
top_5_Economy = full_rank_2019.sort_values(by = 'Economy', ascending = True).head(5)
top_5_Economy = top_5_Economy.loc[:,['City', 'Country', 'Economy']]
top_5_Economy['Economy Top-5'] = top_5_Economy['City']
# top_5_Economy['Economy Top-5_'] = top_5_Economy.iloc[['City']:['Country']].apply(lambda x: ",".join(x.astype(str)), axis=1)
top_5_Economy['Economy Top 5'] = top_5_Economy.iloc[:, [0, 1]].apply(lambda x: " - ".join(x.astype(str)), axis=1)                
top_5_Economy
# Так долго вручную перебирать. Будем писать функцию
# Out:
#              City        Country  Economy  Economy Top-5  \
# 1   New York City  United States        1  New York City
# 15    Los Angeles  United States        2    Los Angeles
# 3           Tokyo          Japan        3          Tokyo
# 19  San Francisco  United States        4  San Francisco
# 48        Houston  United States        5        Houston
#
#                     Economy Top 5
# 1   New York City - United States
# 15    Los Angeles - United States
# 3                   Tokyo - Japan
# 19  San Francisco - United States
# 48        Houston - United States

# %%
# Заготовка для функции. Пробуем
source_df = full_rank_2019
col_number = 9

col_name = source_df.columns[col_number]
top_5 = source_df[source_df[col_name] <= 5].loc[:,['City', 'Country', col_name]].sort_values(by = col_name)
top_5[col_name + ' top'] = top_5['City']
# top_5.reset_index()[col_name + ' top']
top_5 = top_5.reset_index()[col_name + ' top']
top_5
# Выдает серию с индексом
# Out:
# 0      Bern
# 1    London
# 2    Geneva
# 3    Zurich
# 4    Taipei
# Name: Governance top, dtype: object

# %%
# Так добраться до столбца таблицы по номеру:
# full_rank_2019.iloc[:, [5]]
# Так добраться до названия столбца с номером:
full_rank_2019.columns[5]
# Out:
# 'Economy'

# %%
# Функция - вводится датафрейм и порядковый номер столбца
def top_5 (source_df, col_number):
    col_name = source_df.columns[col_number] # Получаем название столбца по номеру
    top_5 = source_df[source_df[col_name] <= 5].loc[:,['City', 'Country', col_name]].sort_values(by = col_name) # Если
    # значение столбца с порядковым номером от 1 до 5, выбираем столбцы Город, Страна, Столбец_с_именем (Места по категории),
    # сортируем по возрастанию (от 1 до 5)
    top_5[col_name + ' top'] = top_5['City'] # Создаем новый столбец с названием города (не будем добавлять еще и страну, 
    # так как здесь нет таких названий, чтобы ввести в заблуждение, и легче воспринимается только город)
    return top_5.reset_index()[col_name + ' top'] # Переназначаем индекс
    
# source_df = full_rank_2019 Это для памяти
# col_number = 5 Это примерно, чему может быть равен номер столбца

top_5_2019_full = pd.DataFrame([]) # Пустой датафрейм, туда будет записывать результаты работы функции

for i in range (full_rank_2019.columns.get_loc("Ranking 2019"), 
               full_rank_2019.columns.get_loc("Mobility and Transportation")+1):
    seria = top_5 (full_rank_2019, i) # Вызываем функцию из датафрейма, номер столбца задан в цикле. 
    # В результат попадает нужная серия с топ-5 по категориям, по порядку нумерации столбцов
    top_5_2019_full[seria.name] = seria # Каждый раз отправляем результат в новый столбец датафрейма
    
top_5_2019_full
# Out:
#   Ranking 2019 top    Economy top Human capital top Social cohesion top  \
# 0           London  New York City            London               Basel
# 1    New York City    Los Angeles       Los Angeles              Zurich
# 2            Paris          Tokyo     New York City              Taipei
# 3            Tokyo  San Francisco            Boston                Bern
# 4        Reykjavik        Houston            Berlin           Liverpool
#
#   Environment top Governance top Urban planning top  \
# 0       Reykjavik           Bern      New York City
# 1      Copenhagen         London             London
# 2      Montevideo         Geneva            Chicago
# 3      Wellington         Zurich               Kiev
# 4       Stockholm         Taipei          Vancouver
#
#   International projection top Technology top Mobility and Transportation top
# 0                       London      Hong Kong                   New York City
# 1                        Paris      Singapore                           Paris
# 2                    Singapore  San Francisco                          London
# 3                    Hong Kong          Dubai                          Berlin
# 4                    Amsterdam         Boston                          Madrid

# %% [markdown]
# ### Шанс на признание. Уровень попадаемости города в топ-N среди всех категорий рейтинга

# %% [markdown]
# В топ-5 по каждой из 9 предметных категории и одного итогового рейтинга попало 28 городов. Если брать каждый раз увеличивающееся число лидеров топ-N, то в него будет попадать все большее число городов. То есть, в определенный момент, все города попадут в топ-N. На каком номере это произойдет? Будем мы ждать до конца списка или на каком-то более раннем количестве N достигнем насыщаемости, и все города отметятся в рейтинге.

# %%
# Посчитать количество вхождений города в топ-5 по всем категориям
# top_5_2019_full.value_counts()
top_5_2019_list = top_5_2019_full.values.tolist()
# type(top_5_2019_list)
top_5_2019_list
# Out:
# [['London',
#   'New York City',
#   'London',
#   'Basel',
#   'Reykjavik',
#   'Bern',
#   'New York City',
#   'London',
#   'Hong Kong',
#   'New York City'],
#  ['New York City',
#   'Los Angeles',
#   'Los Angeles',
#   'Zurich',
#   'Copenhagen',
#   'London',
#   'London',
#   'Paris',
#   'Singapore',
#   'Paris'],
#  ['Paris',
#   'Tokyo',
#   'New York City',
#   'Taipei',
#   'Montevideo',
#   'Geneva',
#   'Chicago',
#   'Singapore',
#   'San Francisco',
#   'London'],
#  ['Tokyo',
#   'San Francisco',
#   'Boston',
#   'Bern',
#   'Wellington',
#   'Zurich',
#   'Kiev',
#   'Hong Kong',
#   'Dubai',
#   'Berlin'],
#  ['Reykjavik',
#   'Houston',
#   'Berlin',
#   'Liverpool',
#   'Stockholm',
#   'Taipei',
#   'Vancouver',
#   'Amsterdam',
#   'Boston',
#   'Madrid']]

# %%
flat_list_5 = []
for sublist in top_5_2019_list:
    for item in sublist:
        flat_list_5.append(item)

flat_list_5

dict = {}

for item in flat_list_5:
    if item is not dict:
        dict[item] = flat_list_5.count(item)
dict

top_5_cities = pd.DataFrame(dict.items(), columns=['City', 'Top-5 counts']).sort_values(
    by = 'Top-5 counts', ascending = False).reset_index()
top_5_cities = top_5_cities.drop('index', 1)
top_5_cities
# Out:
#              City  Top-5 counts
# 0          London             6
# 1   New York City             5
# 2           Paris             3
# 3          Boston             2
# 4   San Francisco             2
# 5          Taipei             2
# 6           Tokyo             2
# 7       Singapore             2
# 8          Zurich             2
# 9     Los Angeles             2
# 10      Hong Kong             2
# 11           Bern             2
# 12      Reykjavik             2
# 13         Berlin             2
# 14      Vancouver             1
# 15          Dubai             1
# 16      Stockholm             1
# 17      Liverpool             1
# 18      Amsterdam             1
# 19        Houston             1
# 20         Geneva             1
# 21           Kiev             1
# 22     Wellington             1
# 23        Chicago             1
# 24     Montevideo             1
# 25     Copenhagen             1
# 26          Basel             1
# 27         Madrid             1

# %%
len(top_5_cities)
# Out:
# 28

# %% [markdown]
# Проверим то же самое на топ из N мест. Чтобы посмотреть, увеличивается ли попадаемость городов в топ-N.
# Если предположить, что в топ-5 по всем категориям попасть трудно, то, возможно, в топ-10 попасть легче, и найдется больше городов, которые устойчиво будут присутствовать в каких-нибудь значениях топ-N, и коэф-т количество попавших в топ-N по всем категориям городов к общему количеству городов в рейтинге по всем категориям выйдет на плоское плато, т.е. насыщение.
# Нюансы:
# 1. В итоговом рейтинге в отчете 2019 г. - 116 городов, на самом деле количество оцениваемых городов больше, и в списке из 116 городов места в отдельных категориях бывают больше 116, а некоторых мест с 1 до 116 в некоторых категориях нет совсем (например в категории Environment из 116 городов нет 8-го места, значит, 8-е место занял какой-то город, который в общем рейтинге занял более низкое место, чем 116; таких случаев много).
# 2. Это выяснилось на этапе проверки значения Coverage (насыщаемость городами рейтинга топ-N). Получалось, что с топ-80-90 показатель насыщаемости становился больше 100%, т.к. длина списка из топ-80-90 становилась 117 (вместо 116 рассматриваемых городов). Начиная с топ-8 появлялся неизвестный город (NaN), который увеличивал длину списка топ-N на 1.
# 3. Скорректирован подсчет: насыщаемость = сумма значений в топ-N, кроме NaN / 116.

# %%
# Функция - вводится датафрейм, порядковый номер столбца и количество рядов n в таблице рейтинга
def top_n (source_df, col_number, n):
    col_name = source_df.columns[col_number] # Получаем название столбца по номеру
    top_n = source_df[source_df[col_name] <= n].loc[:,['City', 'Country', col_name]].sort_values(by = col_name) # Если
    # значение столбца с порядковым номером от 1 до n, выбираем столбцы Город, Страна, Столбец_с_именем (Места по категории),
    # сортируем по возрастанию (от 1 до n)
    top_n[col_name + ' top'] = top_n['City'] # Создаем новый столбец с названием города (не будем добавлять еще и страну, 
    # так как в рейтинге 2019 нет одинаковых названий городов в разных странах, и легче воспринимается только город)
    return top_n.reset_index()[col_name + ' top'] # Переназначаем индекс

coverage = {} # Создаем пустой список для записи насыщаемости рейтинга из N городов повторяющимися городами.

for n in range (1, 100):
    top_n_2019_full = pd.DataFrame([]) # Пустой датафрейм, туда будет записывать результаты работы функции
    for i in range (full_rank_2019.columns.get_loc("Ranking 2019"), 
               full_rank_2019.columns.get_loc("Mobility and Transportation")+1):
        seria = top_n (full_rank_2019, i, n) # Вызываем функцию из датафрейма, номер столбца задан в цикле. 
    # В результат попадает нужная серия с топ-5 по категориям, по порядку нумерации столбцов
        top_n_2019_full[seria.name] = seria # Каждый раз отправляем результат в новый столбец датафрейма
    
    top_n_2019_list = top_n_2019_full.values.tolist()

    flat_list_n = []
    for sublist in top_n_2019_list:
        for item in sublist:
            flat_list_n.append(item)

    flat_list_n

    dict = {}

    for item in flat_list_n:
        if item is not dict:
            dict[item] = flat_list_n.count(item)
    dict

    top_n_cities = pd.DataFrame(dict.items(), columns=['City', 'Top counts']).sort_values(
        by = 'Top counts', ascending = False).reset_index()
    top_n_cities = top_n_cities.drop('index', 1)
    top_n_cities
    
    coverage[n] = top_n_cities['City'].apply(lambda x: 0 if str(x) == 'nan' else 1).sum() / len(full_rank_2019) 
    #был вариант делить на len(flat_list_n), но это не развито к описанию

coverage

df_coverage = pd.DataFrame(coverage.items(), columns=['Number of Cities in the Tops', 'Coverage'])
df_coverage_display = df_coverage.style.format({'Coverage': "{:.1%}"})
df_coverage_display
# Сам датафрейм - это df_coverage, выводим на экран со стилем форматирования % - df_coverage_display
# Out:
# <style  type="text/css" >
# </style><table id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Cities in the Tops</th>        <th class="col_heading level0 col1" >Coverage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row0_col1" class="data row0 col1" >5.2%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row1_col1" class="data row1 col1" >9.5%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row2_col1" class="data row2 col1" >14.7%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row3_col1" class="data row3 col1" >19.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row4_col1" class="data row4 col1" >24.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row5_col1" class="data row5 col1" >27.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row6_col1" class="data row6 col1" >31.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row7_col1" class="data row7 col1" >33.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row8_col0" class="data row8 col0" >9</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row8_col1" class="data row8 col1" >36.2%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row9_col0" class="data row9 col0" >10</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row9_col1" class="data row9 col1" >41.4%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row10_col0" class="data row10 col0" >11</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row10_col1" class="data row10 col1" >44.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row11_col0" class="data row11 col0" >12</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row11_col1" class="data row11 col1" >49.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row12_col0" class="data row12 col0" >13</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row12_col1" class="data row12 col1" >52.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row13_col0" class="data row13 col0" >14</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row13_col1" class="data row13 col1" >54.3%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row14_col0" class="data row14 col0" >15</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row14_col1" class="data row14 col1" >56.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row15_col0" class="data row15 col0" >16</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row15_col1" class="data row15 col1" >59.5%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row16_col0" class="data row16 col0" >17</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row16_col1" class="data row16 col1" >62.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row17_col0" class="data row17 col0" >18</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row17_col1" class="data row17 col1" >64.7%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row18_col0" class="data row18 col0" >19</td>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row18_col1" class="data row18 col1" >66.4%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_1e2d89d6_47c6_11ec_ad7a_0862661baed1row19_col0" class="data row19 col0" >20</td>
#                         <td id="

# %%
df_coverage.plot(x = 'Number of Cities in the Tops', y = 'Coverage', legend = False, figsize=(8,4))
plt.ylabel('Coverage')
plt.title('Уровень попадаемости города в топ-N по всем категориям рейтинга 2019 г.')
# Out:
# Text(0.5, 1.0, 'Уровень попадаемости города в топ-N по всем категориям рейтинга 2019 г.')
